# %% [markdown]
# <div style="border: 5px solid dodgerblue; padding: 15px">
#
# Юля, привет!
#
# Меня зовут Аня Львова, я буду проверять твой проект. Предлагаю общаться на "ты", но если это некомфортно, просто дай знать, и мы перейдем на "вы":)
#
# Сразу напишу, что моя главная цель – не искать ошибки в твоем коде, а дать персональную обратную связь, чтобы помочь тебе профессионально развиваться и стать аналитиком данных.
#
# Я написала более детальные комментарии ниже, они выделены заголовком и цветами. Пожалуйста, не удаляй и не изменяй мои комментарии.
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Так я обозначаю верные части и те, которые мне особенно понравились: эффективные или красивые решения.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Так я отмечу, что в следующий раз можно сделать по-другому. Исправлять недочёты, указанные в этих комментариях необязательно.
# </div>
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <font size='4'><b>❌ Комментарий ревьюера</b></font>
#
# Так я укажу на не самые удачные моменты: их нужно будет учесть и исправить.
# </div>
#
# Предлагаю работать в диалоге. В ответ на мои комментарии можешь дать свои: понятны ли мои заметки, что и как ты поменяешь. Можешь выделить их другим цветом.
#
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
#
# Это поможет мне будет выполнить повторное ревью оперативнее.
# </div>

# %% [markdown]
# <div style="border: 5px solid dodgerblue; padding: 15px">
#
# <font size='4'><b>Комментарий ревьюера 2</b></font>
#
# Юля, спасибо за быстрые доработки! Теперь все хорошо, могу принять проект.
#
# Я постаралась ответить на все твои комментарии. На всякий случай возвращаю тебе проект, чтобы удостовериться, что я смогла все понятно объяснить. Если будут вопросы, напиши их, пожалуйста, тоже с цифрой 2. Если все понятно, то возвращай мне тетрадку, и я ее сразу приму
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Мои комментарии 2:</b>
#
# Все коментарии понятны, спасибо!
#
# У меня осталось пару малельких вопросов:
#
#     - Можно ли отфильтровать или передать в другой массив все числовые данные? Не перечисляя нужные столбцы.
#     - Как сгладить график? Согласна, что в том случае лучше не применять, и всёже прошу поделиться информацией.
#
# </div>

# %% [markdown]
# <div style="border: 5px solid dodgerblue; padding: 15px">
#
# <font size='4'><b>Комментарий ревьюера 3</b></font>
#
# 1. Чтобы отфильтровать данные по типу есть метод select_dtypes https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html
#
# 2. Про сглаживание.
#
# Во-первых, можно сгладить с помощью интерполяции, импортировав соответствующий модуль. Вот пример:
# https://www.geeksforgeeks.org/how-to-plot-a-smooth-curve-in-matplotlib/
#
# Во-вторых, можно предварительно агрегировать данные. Так часто поступают с временными значениями. Например, когда день ото дня показатели сильно скачут, то применяют среднее за неделю. Вот так: https://www.geeksforgeeks.org/how-to-make-a-time-series-plot-with-rolling-average-in-python/
#
# Еще один способ попроще: вместо линейной диаграммы сделать столбиковую;) Тогда тренд все равно будет заметен, а флуктуации его не так загрязнят.
#
#
# А проект теперь принимаю и желаю успехов в дальнейшей учебе!
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Немного про оформление. Ты просто скопировала задание себе в тетрадку. В некоторых случаях это тоже выход:) Но я бы рекомендовала тебе расписывать цель и основные этапы своими словами. Это покажет твое ответственное отношение к проекту и проработанность материала.
#
# А еще в больших проектах классно добавлять интерактивное содержание: оно позволит лучше ориентироваться в проекте тому, кто будет его читать. А тебе структурировать мысли и не пропустить какой-нибудь раздел.
# </div>
#
# <div class="alert alert-info"> <b>Мои комментарии:</b> Да, за основу была взята тетрадка с заданием и в ней выполнялась работа. Хотелось сохранить структуру и список задач для ревьюера. Это всё нужно удалять из проектов Практикума?
#
# Была делема писать адресовываясь к Ревьюеру или к заказчику?
# Понятно, что для заказчика проект был бы оформлен немного по другому.
#
# Гиперссылки в MD ещё не освоила, учту в следующем проекте.
#
# Ещё вопрос, например как лучше писать "посмотрим сколько пустых значений..." или "рассмотрю сколько пустых значений..." для ревьюера и для заказчика??
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера 2</b></font>
#
# Да, рекомендую писать комментарии так, будто их будут читать коллеги/ревьюер/заказчик. Сразу привыкать;) Поэтому важно, чтобы в нем была логика и последовательность, чтобы читающие могли понять, почему ты поступаешь так или иначе
# </div>

# %% [markdown]
# ### Изучение общей информации.

# %%
# Импорт библиотек
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Чтение файла данных
try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv')

# %%
# Проверка количества дубликатов
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Отличное использование метода try...except.
#
# Хорошо, что проверила на явные дубликаты
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Лучше выделять каждый логический блок в отдельную ячейку. В твоем случае – разделить импорт библиотек и чтение датасета. Во-первых, так легче читать код. Во-вторых, это оптимальнее. Например, если тебе понадобится перепрочитать датасет, то не придется заодно переимпортировать все библиотеки
#
# </div>

# %%
# пример данных в несколько строк
data.sample(8).T
# Out:
#                                     22129                1968   \
# total_images                           11                   10
# last_price                      6000000.0            5200000.0
# total_area                           53.0                 50.0
# first_day_exposition  2018-07-17T00:00:00  2017-08-21T00:00:00
# rooms                                   2                    1
# ceiling_height                        2.8                  2.7
# floors_total                          3.0                 15.0
# living_area                          30.0                 20.0
# floor                                   2                   15
# is_apartment                          NaN                  NaN
# studio                              False                False
# open_plan                           False                False
# kitchen_area                          8.5                 15.0
# balcony                               1.0                  NaN
# ...

# %%
# общая инормация о массиве
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Убрать текстовую строку над графиками можно двумя способами:
#
# 1) поставить в конце кода для графика `;`
#
# 2) добавить в конце строку `plt.show()`
# </div>

# %%
data[['locality_name', 'days_exposition']].sample(10)
# Out:
#          locality_name  days_exposition
# 4752    посёлок Мурино             12.0
# 6031              Луга              NaN
# 2162           Кудрово              NaN
# 19812  Санкт-Петербург             43.0
# 5276   Санкт-Петербург             38.0
# 10191  Санкт-Петербург            293.0
# 10036  Санкт-Петербург              NaN
# 5353            Мурино              NaN
# 883             Выборг            257.0
# 23224  Санкт-Петербург            330.0

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Вот так можно добавить красоты в проверку пропусков
# </div>

# %%
# код ревьюера
data.isna().mean().round(4).to_frame().sort_values(by=0).style.format('{:.2%}').background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_caaa3_row0_col0,#T_caaa3_row1_col0,#T_caaa3_row2_col0,#T_caaa3_row3_col0,#T_caaa3_row4_col0,#T_caaa3_row5_col0,#T_caaa3_row6_col0,#T_caaa3_row7_col0,#T_caaa3_row8_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_caaa3_row9_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_caaa3_row10_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_caaa3_row11_col0{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_caaa3_row12_col0{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_caaa3_row13_col0,#T_caaa3_row14_col0,#T_caaa3_row15_col0,#T_caaa3_row16_col0{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_caaa3_row17_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_caaa3_row18_col0{
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Было бы здорово писать в конце раздела небольшие выводы: что ты заметила, что показал обзор данных, что планируешь делать дальше
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
# посмотрим сколько пустых значений в названии населённого пункта
print(len(data[data['locality_name'].isna()]), ' из ', data.shape[0], round(len(data[data['locality_name'].isna()]) / data.shape[0],4))
# Out:
# 49  из  23699 0.0021

# %% [markdown]
# Т.к. данных с отсутствующим населенным пунктом очень мало, а населённый пункт очень важен для исследования, считаю, что эти данные лучше отсечь.

# %%
#удаление строк, в столбцах которых locality_name = NaN
data = data.dropna(subset=['locality_name'])
data.shape[0]
# Out:
# 23650

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Молодец, что используешь метод dropna, а также пишешь, какую часть датасета ты удаляешь – это помогает не перефильтровать данные
# </div>

# %% [markdown]
# Определяю категории населённых пунктов

# %%
def categorize_locality(row):
    try:
        if 'поселок' in row:
            return 'поселок'
        elif 'село' in row:
            return 'село'
        elif 'деревня' in row:
            return 'деревня'
        elif 'товарищество' in row:
            return 'товарищество'
        elif 'Пансионат' in row:
            return 'пансионат'
        else:
            return 'город'
    except:
        return 'город'
    
data = data.apply(lambda x: x.replace({'ё':'е'}, regex=True))
data['locality_type'] = data['locality_name'].apply(categorize_locality)

#data.info()

# %% [markdown]
# Считаю, что если нет данных о количестве дней в продаже, значит недвижимость не была продана и эти данные лучше не брать для анализа

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Согласна
# </div>

# %%
#удаление строк, в столбцах которых days_exposition = NaN
data = data.dropna(subset=['days_exposition'])
data.shape[0]
# Out:
# 20470

# %%
#посмотрим сколько данных без пропусков
best_data = data.dropna()
best_data.shape[0]
# Out:
# 250

# %% [markdown]
# Предполагаю, что населённых пунктов с одинаковыми именами в пределах области нет. Префикс перед именем лучше убрать

# %%
data = data.apply(lambda x: x.replace({'поселок при железнодорожной станции ':''}, regex=True))
data = data.apply(lambda x: x.replace({'поселок городского типа имени ':''}, regex=True))
data = data.apply(lambda x: x.replace({'поселок городского типа ':''}, regex=True))
data = data.apply(lambda x: x.replace({'городской поселок ':''}, regex=True))
data = data.apply(lambda x: x.replace({'поселок при железнодорожной станции ':''}, regex=True))
data = data.apply(lambda x: x.replace({'коттеджный поселок ':''}, regex=True))
data = data.apply(lambda x: x.replace({'поселок станции ':''}, regex=True))
data = data.apply(lambda x: x.replace({'поселок ':''}, regex=True))
data = data.apply(lambda x: x.replace({'село ':''}, regex=True))
data = data.apply(lambda x: x.replace({'деревня ':''}, regex=True))
data = data.apply(lambda x: x.replace({'садовое товарищество ':''}, regex=True))
data = data.apply(lambda x: x.replace({'садоводческое некоммерческое товарищество ':''}, regex=True))
data = data.apply(lambda x: x.replace({'садовое товарищество ':''}, regex=True))
data = data.apply(lambda x: x.replace({'Пансионат ':''}, regex=True))
# и проверяю дубликаты
data.duplicated().sum()
# Out:
# 0

# %%
data['locality_name'].value_counts().head(13)
# Out:
# Санкт-Петербург    13638
# Мурино               551
# Кудрово              441
# Шушары               408
# Всеволожск           339
# Колпино              308
# Пушкин               307
# Парголово            302
# Гатчина              268
# Выборг               208
# Петергоф             176
# Сестрорецк           163
# Красное Село         158
# Name: locality_name, dtype: int64

# %% [markdown]
# Заполним 'is_apartment' как False, т.к. апартаменты достаточно редкое явление.

# %%
data.groupby('is_apartment')['is_apartment'].count()
data['is_apartment'] = data['is_apartment'].fillna(False)

# Код добавлен после ревью
data['is_apartment'] = data['is_apartment'].astype('bool')

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Да, я бы сделала так же
# </div>

# %% [markdown]
# Количество балконов на "0", если количество не указано.

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# Заменю расстояние до центра в значение в километрах для удобства группировки и заполню пропуски. Отсутствующие значения заменю на -1.

# %%
data['cityCenters_nearest'] = data['cityCenters_nearest'].fillna(-1000)

data['cityCenters_nearest'] = round(data['cityCenters_nearest'] / 1000, 0).astype('int')

data['cityCenters_nearest'].sample(3)

#data.info()
# Out:
# 406      14
# 702       9
# 22138    -1
# Name: cityCenters_nearest, dtype: int64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# И можно было бы сразу перевести данные в int, раз мы их округлили до целочисленных
# </div>
#
# <div class="alert alert-info"> <b>Комментарии для ревьюера:</b> Перевести эти данные я пыталась. В поле cityCenters_nearest много пропусков. Которые определяются как тип float. Перевести эти данные методами astype или int() не получилось, поэтому оставила как есть.
#
# Подскажи пожалуйста как справиться с этими данными? Буду очень благодарна.</div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера 2</b></font>
#
# Не получалось перевести из-за пропусков. Есть два основных способа работы с пропусками: оставить как есть или заполнить чем-то. Заполнить можно вычисленными данными (средние/медианы и тп), а можно значением-заглушкой. Например, -1. Так ты не перепутаешь из с реальными значениями и сэкономишь память
# </div>

# %% [markdown]
# Недостающие значения высоты потолков беру как медианное значение по типу населённого пункта.

# %%
  
for t in data['locality_type'].unique():
    q = data.loc[(data['locality_type'] == t), 'ceiling_height'].median()
    data.loc[(data['locality_type'] == t) & (data['ceiling_height'].isna()), 'ceiling_height'] = q
    display(q)
# Out:
# 2.6
# 2.65
# 2.7
# 2.55
# 2.6

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# А вот тут кажется слишком грубым округлением: в городе Санкт-Петербург есть старинные дома с высокими потолками, хрущевки и современные новостройки. Высота потолков больше зависит от типа дома, нежели от населенного пункта
#
# </div>

# %%
len(data['ceiling_height'])
# Out:
# 20470

# %% [markdown]
# Если высота потолков указана более 24 метров, уменьшаю её в 10 раз, т.к. это похоже на ошибку

# %%
rows = data['ceiling_height'] > 24

data.loc[rows, 'ceiling_height'] = data.loc[rows, 'ceiling_height'] / 10

data[rows]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17   3600000.0        55.2  2018-07-12T00:00:00      2
# 4643              0   4300000.0        45.0  2018-02-01T00:00:00      2
# 4876              7   3000000.0        25.0  2017-09-27T00:00:00      0
# 5246              0   2500000.0        54.0  2017-10-13T00:00:00      2
# 5669              4   4400000.0        50.0  2017-08-08T00:00:00      2
# 5807             17   8150000.0        80.0  2019-01-09T00:00:00      2
# 10773             8   3800000.0        58.0  2017-10-13T00:00:00      2
# 11285             0   1950000.0        37.0  2019-03-20T00:00:00      1
# 14382             9   1700000.0        35.0  2015-12-04T00:00:00      1
# 17857             1   3900000.0        56.0  2017-12-22T00:00:00      3
# 18545             6   3750000.0        43.0  2019-03-18T00:00:00      2
# 20478            11   8000000.0        45.0  2017-07-18T00:00:00      1
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Молодец, что заметила
# </div>

# %% [markdown]
# Считаю, что высота потолков менее 2 метров и более 10 это ошибка. Таких данных не много, всего 7 записей. Их лучше убрать из анализа.

# %%
data = data.loc[(data['ceiling_height'] >= 2) & (data['ceiling_height'] <= 10)]
data.shape
# Out:
# (20463, 23)

# %% [markdown]
# <div class="alert alert-info"> <b>Мои комментарии: </b> Заполнение пропусков с этажностью дома, если известно на каком этаже расположена квартира. Предполагаю взять 7 наиболее распространённых этажностей и округлять до ближайшего.</div>

# %%
def categorize_floor(floor):
    try:
        if floor == 1:
            return 1
        elif 1 <= floor <= 5:
            return 5
        elif 6 <= floor <= 12:
            return 12
        elif 13 <= floor <= 17:
            return 17
        elif 18 <= floor <= 25:
            return 25
        elif 26 <= floor <= 33:
            return 33
        elif 34 <= floor <= 50:
            return 50
        elif floor > 50:
            return 100
    except:
        pass

rows = data['floors_total'].isna()
data.loc[rows, 'floors_total'] = data.loc[rows, 'floor'].apply(categorize_floor)
data[rows]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 186              12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237               4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457               4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671               4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757              5   3600000.0        39.0  2017-04-22T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 22542             5   8500000.0        63.5  2017-05-24T00:00:00      2
# 22656             4   4574160.0        64.5  2017-04-02T00:00:00      2
# 22808             0  14569263.0       110.4  2016-11-20T00:00:00      3
# 23590             0  21187872.0       123.3  2017-04-25T00:00:00      3
# 23658             6   3063600.0        43.8  2016-11-28T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Непонятно, зачем здесь такая категоризация этажей
#
# </div>

# %% [markdown]
# Предполагаю, что количество комнат не может быть равно нулю. Задаю значение дня какиех квартир равное одному.

# %%
data.loc[data['rooms'] == 0, 'rooms'] = 1

# %% [markdown]
# Предполагаю определить жилую площадь как отношение медианных значений по группам по количеству комнат.

# %%
#row = []

for t in data['rooms'].unique():
    row = (data['rooms'] == t) & (data['living_area'].isna())

    q = data.loc[(data['rooms'] == t), 'living_area'].median() / data.loc[(data['rooms'] == t), 'total_area'].median()

    data.loc[row, 'living_area'] = q * data.loc[row, 'total_area'] 

#data.info()

# %% [markdown]
# Предполагаю определить **площадь кухни** как отношение медианных значений по группам по количеству комнат.

# %%
#row = []

for t in data['rooms'].unique():
    row = (data['rooms'] == t) & (data['kitchen_area'].isna())
    q = data.loc[(data['rooms'] == t), 'kitchen_area'].median() / data.loc[(data['rooms'] == t), 'total_area'].median()

    #display(q)
    data.loc[row, 'kitchen_area'] = q * data.loc[row, 'total_area'] 

#data.info()

# %% [markdown]
# Предполагаю, что цены менее 50000 за недвижимость не может быть, скорее всего это ошибка, исправлю её умножив значение на 1000

# %%
rows = data['last_price'] <= 50000

data.loc[rows, 'last_price'] = data.loc[rows, 'last_price'] * 1000

data[rows]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7  12190000.0       109.0  2019-03-20T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 8793            2.75          25.0         32.0     25         False  ...
#
#       balcony    locality_name  airports_nearest  cityCenters_nearest  \
# 8793      0.0  Санкт-Петербург           36421.0                    9
#
#      parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 8793              1.0          805.0               0.0            NaN
#
#       days_exposition  locality_type
# 8793              8.0          город
#
# [1 rows x 23 columns]

# %% [markdown]
# Проверю сколько данных пропущено по другим полям:

# %%
data.pivot_table(index='locality_name', values=['airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest'], aggfunc=['count', 'mean']).sample(30)
# Out:
#                            count                                       \
#                 airports_nearest cityCenters_nearest parks_around3000
# locality_name
# Глинка                         0                   1                0
# Селезнево                      0                   5                0
# Тесово-4                       0                   1                0
# Тосно                          0                  94                0
# Поляны                         0                   4                0
# Кингисепп                      0                  95                0
# Заклинье                       0                   2                0
# Кондратьево                    0                   1                0
# Сланцы                         0                  91                0
# Громово                        0                   4                0
# Извара                         0                   5                0
# ...

# %% [markdown]
# В данных о расстоянии до центра, расстоянии до аэропорта, парка, водоёма слишком много пробелов. Считаю не правильным заполнять эти данные какими-то средними значениями.
# Для небольших населённых пунктов можно было бы заполнить по аналогии, но пустых значений слишком много.
# На мой взгляд эти значения не очень важны и можно их оставить с пробелами.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Здорово, что в этом разделе рассуждаешь о причинах пропусков и обосновываешь свои действия
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <font size='4'><b>❌ Комментарий ревьюера</b></font>
#
# Еще по заданию нужно было изменить неподходящие типы данных. Как думаешь, есть такие в датасете?
# </div>
#
# <div class="alert alert-info"> <b>Мои комментарии:</b>
#
# В ходе реализации проекта были изменены сдедующие типы данных: first_day_exposition на datetime, days_exposition на int.
# Сегодня заметила is_apartment, преобразовала в bool.
#
# Других данных для преобразования не заметила.
#
# Рассмотривала заменить weekday на именованные значения, но не знаю как это сделать из datetime сделать. Подскажи пожалуйста как? Использовать что-то типа if или case не хочется.
# Хранить день в int удобнее с точки зрения ресурсов ПК, но для реального заказчика считаю лучше показать названия.
#
# Ещё, подскажи пожалуйста как выгрузить итоговый датафрэйм в excel или csv? Мочно ли это сделать если тетрадка в виртуальной среде Практикума?
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера 2</b></font>
#
# 1. Я обычно оставляю weekday числом, так на графиках автоматически будет сортировка. А именованные значения добавляю в отдельную колонку, для этого есть `.dt.day_name()`, написала ниже.
#
# 2. Для скачивания есть методы `.to_csv()` или `.to_excel()`. Я стараюсь избегать в данных xlsx-формата, а чтобы датасет удобно открывался в excel, сохраняю csv с tab-разделителем. Вот так:
#
# `data.to_csv(file_path, sep='\t', index = False)`
#
# К сожалению, из виртуальной среды не так просто скачать файлы локально. Самый простой способ – это скачать исходные данные и jupyter-notebook, открыть его локально и уже оттуда скачать.
# </div>

# %%
# код ревьюера
data['first_day_exposition'].dt.day_name()

# %% [markdown]
# ### Новые данные.

# %% [markdown]
# Цена за квадратный метр:

# %%
data['price_per_meter'] = data.last_price / data.total_area
data.sort_values(by='price_per_meter', ascending=False).head(3)
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 12971            19  763000000.0       400.0  2017-09-30T00:00:00      7
# 1436             19  330000000.0       190.0  2018-04-04T00:00:00      3
# 14706            15  401300000.0       401.0  2016-02-20T00:00:00      5
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 12971            2.65          10.0        250.0     10         False  ...
# 1436             3.50           7.0         95.0      5         False  ...
# 14706            2.65           9.0        204.0      9         False  ...
#
#          locality_name  airports_nearest  cityCenters_nearest  \
# 12971  Санкт-Петербург           25108.0                    4
# 1436   Санкт-Петербург           23011.0                    1
# 14706  Санкт-Петербург           21912.0                    2
#
#        parks_around3000 parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Обращаться к столбцам можно и так, и так: и `data.last_price`, и `data['last_price']`. Но лучше выбрать какой-то один способ и использовать его. Единообразный код удобнее читать
# </div>

# %% [markdown]
# Замена типа данных для даты из строковой в datetime для удобства операций в дальнейшем
#
# Добавлю поля "день недели" - weekday, "мецяц" - month и "год" - year, публикации объявления

# %%
data['first_day_exposition'] = pd.to_datetime(
    data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

data['weekday'] = data['first_day_exposition'].dt.weekday 

data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month

data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

data.sample(3)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 14816             2   2100000.0        34.2           2017-08-08      1
# 2844              6   5420000.0        45.0           2017-09-26      2
# 626               9   1990000.0        33.0           2017-05-18      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 14816            2.60          11.0    17.000000      9         False  ...
# 2844             2.65           6.0    22.000000      1         False  ...
# 626              2.65           5.0    16.044199      3         False  ...
#
#        parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 14816               0.0            NaN               0.0            NaN
# 2844                1.0          742.0               1.0          215.0
# 626                 1.0          587.0               0.0            NaN
#
#       days_exposition  locality_type  price_per_meter  weekday  month  year
# ...

# %%
# Изменяю тип данных для days_exposition
data.days_exposition = data.days_exposition.astype('int')

# Функция для сдвига даты
def last_day(item):
    first_day_exposition = item['first_day_exposition']
    days_exposition = item['days_exposition']
    return first_day_exposition + pd.DateOffset(days=days_exposition)

# Создаю столбец с датой снятия объявления
data['last_day_exposition'] = data.apply(last_day, axis=1)

# Создаю столбец с днём недели снятия объявления
data['last_weekday'] = data['last_day_exposition'].dt.weekday

# Пример обновлённого набора данных 
data.sample(3)

#data.info()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19531            18   8600000.0        73.0           2018-11-21      2
# 16488            15   8000000.0        70.2           2019-03-05      3
# 21969             3  13500000.0        95.1           2017-11-10      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 19531            2.75          16.0         41.0      2         False  ...
# 16488            2.70          12.0         44.4      5         False  ...
# 21969            2.65          12.0         56.2      7         False  ...
#
#        ponds_around3000  ponds_nearest  days_exposition  locality_type  \
# 19531               2.0          450.0              105          город
# 16488               0.0            NaN               39          город
# 21969               1.0          295.0               90          город
#
#       price_per_meter  weekday  month  year  last_day_exposition  last_weekday
# ...

# %% [markdown]
# Категория этажа:

# %%
# Функция для определения категории этажа
def floors_group(item):
    #display(item)
    floors_total = item['floors_total']
    floor = item['floor']
    if floors_total == floor:
        return 'последний'
    elif floor == 1:
        return 'первый'
    return 'другой'

# %%
# Добавления поля с категорией этажа
data['floors_group'] = data.apply(floors_group, axis=1)
# Пример обновлённого набора данных 
data.sample(3)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 15271            20  12300000.0        72.0           2016-01-04      2
# 326               6   3900000.0        45.4           2017-09-22      2
# 2745              1   3700000.0        39.2           2018-03-14      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 15271            2.85          13.0         45.0      7         False  ...
# 326              2.65           5.0         27.8      3         False  ...
# 2745             2.65          12.0         20.1      2         False  ...
#
#        ponds_nearest  days_exposition  locality_type  price_per_meter weekday  \
# 15271          533.0              262          город    170833.333333       0
# 326            920.0              121          город     85903.083700       4
# 2745           134.0              266          город     94387.755102       2
#
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Верно
# </div>

# %%
#data.hist('parks_nearest', bins=100, range=(1, 100))
last_weekday = data.groupby('last_weekday').count()['rooms'].reset_index(drop=True)

# Код добавлен после ревью
last_weekday.plot(ylim=(1000, 4000));
last_weekday

#display(data.parks_nearest.mean())
#display(data.parks_nearest.median())
#data['total_area'].value_counts()
# Out:
# 0    3328
# 1    3848
# 2    3022
# 3    3085
# 4    3021
# 5    2276
# 6    1883
# Name: rooms, dtype: int64

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Было бы здорово визуализировать получившийся результат
# </div>

# %% [markdown]
# В изученном наборе данных представлены квартиры общей площадью от 12 до 900 квадратных метров. Основной разброс значений от 18 до 115 метров.
#
# Жилая площадь от 2 до 410 метров. Основной набор значений от 14 до 55 метров.
#
# Размеры кухни от 1,3 до 112 метров. Основной набор значений от 5 до 21 метра.
#
# Количество комнат от 1 до 19. Основной набор значений от 1 до 4 шт.
#
# Высота потолков от 2 до 10 метров. Основной набор значений от 2,5 до 3 метров.
#
# Квартиры продаются с 1 до 33 этажа. Основной набор значений от 1 до 19 этажа. Среднее значение 5,98. Медианное 4.
#
# Примерно 10% квартир на первых и последних этажах.
#
# Всего этажей в домах от 1 до 60. Чаще других от 5-го до 25-го этажей. Среднее значение 10,87. Медианное 9.
#
# Расстояние от центра от 0 до 55 км. Основной набор значений от 0 до 18 км. Среднее значение 14,3. Медианное 13.
#
# Расстояние от аэропорта от 20 до 73 км. Основной набор значений от 20 до 55 км. Среднее значение 28,85. Медианное 26,78.
#
# Расстояние до ближайшего парка от 1 до 3200 м. Основной набор значений от 10 до 1000. Среднее значение 491. Медианное 451.
#
# В будние дни опубликовывалось приблизительно от 3 до 4 тысяч объявлений. В выходные, субботу и воскресенье, примерно в два раза меньше.
#
# Если предположить, что последний день публикации объявления — это день продажи, то из предоставленных данных видно: В будние дни было сделано приблизительно от 3 до 4 тысяч продаж. Во вторник продаж примерно на 30% больше чем в другие будние дни.
# В субботу продаж заметно меньше чем в будние дни. В воскресенье, продаж меньше примерно в два раза.

# %%
data.hist('days_exposition', bins=24, range=(38, 62))
#data.groupby('rooms')['days_exposition'].mean()
display(data.days_exposition.mean())
display(data.days_exposition.median())
#data['days_exposition'].value_counts()
# Out:
# 180.7744709964326
# 95.0

# %%
# Код добавлен после ревью
data.boxplot(column='days_exposition');

# %%
data.boxplot(column='days_exposition')
plt.ylim(44, 232)
plt.show()

# %% [markdown]
# В данном наборе представлены квартиры которые продавались от 1 дня до 4,5 лет. Очень заметны всплески на 45 и 60 дней. Возможно это связано с периодом размещения объявления.
# Период продажи от 44 до 232 считается нормальным. До 44 дней очень быстрым. Более 232 дней очень долгим.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Ящик с усами удобен тем, что показывает сразу несколько статистик о данных, в том числе выбросы, не только медиану. Поэтому лучше делать его в 2 шага в данном случае: сначала без ограничений по оси, а уже потом с параметром ylim.
#
# Еще рекомендую для графиков делать заголовки и подписи к осям
#
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Создание массива с числовыми значениями и матрицы корреляции по ним

# %%
# Датафрэйм с числовыми значениями:
# Код изменён после ревью
num_data = data[['total_images', 'last_price', 'total_area', 'ceiling_height', 'floors_total', 'living_area', 'floor', 'kitchen_area', 'days_exposition', 'price_per_meter']]

print(num_data.corr())
# Out:
#                  total_images  last_price  total_area  ceiling_height  \
# total_images         1.000000    0.094950    0.106067        0.044888
# last_price           0.094950    1.000000    0.643286        0.253835
# total_area           0.106067    0.643286    1.000000        0.357582
# ceiling_height       0.044888    0.253835    0.357582        1.000000
# floors_total         0.005736   -0.004974   -0.070207       -0.075815
# living_area          0.092472    0.575940    0.944769        0.340344
# floor                0.027366    0.026621   -0.024462       -0.042987
# kitchen_area         0.097841    0.470052    0.630073        0.307458
# days_exposition     -0.027474    0.080892    0.149541        0.104565
# price_per_meter      0.124871    0.736612    0.305011        0.274683
#
#                  floors_total  living_area     floor  kitchen_area  \
# total_images         0.005736     0.092472  0.027366      0.097841
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Можно сделать вот так:
#
# </div>

# %%
# код ревьюера
import seaborn as sns

for_corr = data[['last_price', 'total_images', 'total_area', 'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor', 'kitchen_area', 'balcony', 'days_exposition']]
sns.heatmap(for_corr.corr()[['last_price']].sort_values('last_price', ascending=False));

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <font size='4'><b>❌ Комментарий ревьюера</b></font>
#
# Еще важно разделять тип данных: как удобно хранить данные и что этот тип означает. День недели записан в численном формате, но по смыслу это категориальные, а не порядковые данные, то есть считать корреляцию с ним нельзя. Потому что если в цене четыре вдвое больше двух, а два вдвое больше одного, то для дней недели эта логика не работает
# </div>
#
# <div class="alert alert-info"> <b>Мои комментарии:</b> Деление данных на Категориальные и Числовые часто кажется условным. Например, Этаж или Количество этажей, Количество балконов, Количество комнат, Количество фотографий.
# Стоит ли их брать в корреляцию?
#     Данные нужно разделять прямо на разные датафрэймы, или речь ижёт об осознанном разделении для аналитика?
#
# Подскажите как можно отфильтровать данные одной командой. Пандас или Питон наверняка это умеют, например метод discribe() по умолчанию выводит только числовые.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера 2</b></font>
#
# Тут нужно подумать самой и оценить, о каких данных идет речь.
#
# Попробую расписать свой пример подробнее. Если упростить, корреляцию можно трактовать так: чем больше переменная x, тем больше переменная y. Чем больше площадь квартиры, тем больше цена. Чем больше в квартире балконов, тем выше цена. Единицы измерения понятны: считаем цену в рублях, площадь в квадратных метрах, балконы – в балконах. Если корреляция равна единице, то при увеличении балконов вдвое цена тоже вырастет вдвое. Можем их количество умножить на что-то или суммировать.
#
# А вот в чем мы считаем дни недели? И можно ли понедельник умножить на два, чтобы получить вторник? А если субботу разделить на 3?
#
# <img src="https://globalcentre.hse.ru/data/2016/04/13/1129731897/1-.jpg" alt='strength of correlation table' width="400" height="200">
#
# </div>

# %% [markdown]
# **Анализ цены:**
#
# Как видно из матрицы корреляции цена на квартиру зависит от её площади. Есть небольшая зависимость от числа комнат, этот параметр явно тесно связан с площадью. Другие зависимости очень слабые.
#
# Посмотрим для наглядности диаграмму рассеивания этих параметров

# %%
price_addictions = data[['last_price', 'total_area', 'rooms', 'ceiling_height','living_area','kitchen_area']]

pd.plotting.scatter_matrix(price_addictions, figsize=(12, 12))
plt.show()

# %% [markdown]
# Обзор зависимостей от даты и этажа.

# %%
pd.plotting.scatter_matrix(data[['last_price', 'weekday', 'month', 'year', 'last_weekday']], figsize=(12, 12))
plt.show()

# %% [markdown]
# Средняя цена квартиры в зависимости от категории этажа, на котором она расположена.

# %%
#data.groupby('floors_group')['floor'].mean()
floors_group = data.pivot_table(index = ['floors_group'], values = 'last_price', aggfunc = ['mean'])
floors_group.columns = ['mean_price']
floors_group
# Out:
#                 mean_price
# floors_group
# другой        6.420798e+06
# первый        4.508579e+06
# последний     6.946964e+06

# %% [markdown]
# Рассмотрим среднюю цену квадратного метра в десяти наиболее крупных населённых пунктах по количеству объявлений.

# %%
#data.groupby('locality_name')['locality_name'].count()
great_locality = data.pivot_table(index = ['locality_name'], values = 'price_per_meter', aggfunc = ['count', 'mean'])
great_locality.columns = ['ad_count', 'meter_mean']
great_locality = great_locality.reset_index(drop=False)
great_locality.sort_values(by='ad_count', ascending=False).head(10)
# Out:
#        locality_name  ad_count     meter_mean
# 207  Санкт-Петербург     13632  112421.718514
# 138           Мурино       551   85743.233293
# 100          Кудрово       441   94408.041602
# 274           Шушары       408   78010.167480
# 33        Всеволожск       339   68570.615292
# 86           Колпино       308   74865.364347
# 188           Пушкин       307  102074.629153
# 158        Парголово       302   89505.043917
# 41           Гатчина       268   67928.326990
# 34            Выборг       208   57084.582948

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Еще было бы здорово визуализировать получившиеся таблицы. Например, вот так:
#
# </div>
#
# <div class="alert alert-info"> <b>Мои комментарии:</b> Считаю именно тут выводить график это лишнее. Краткая таблица тут вполне достаточна.
#
# Тут хочется избавиться от знаков после запятой. astype не работает. Подскажи пожалуйста как лучше представить данные на выводе? И ещё, если можно, сдвиг разрядов, например так: "99 999".
#
# Большое спасибо за пример хорошего оформления графика, моих знаний пока не достаточно.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера 2</b></font>
#
# Для округления можно использовать `round()`
# </div>

# %%
# код ревьюера

great_locality['meter_mean'] = round(great_locality['meter_mean']).astype(int)
great_locality.sort_values(by='ad_count', ascending=False).head(10)
# Out:
#        locality_name  ad_count  meter_mean
# 207  Санкт-Петербург     13632      112422
# 138           Мурино       551       85743
# 100          Кудрово       441       94408
# 274           Шушары       408       78010
# 33        Всеволожск       339       68571
# 86           Колпино       308       74865
# 188           Пушкин       307      102075
# 158        Парголово       302       89505
# 41           Гатчина       268       67928
# 34            Выборг       208       57085

# %%
# код ревьюера 
locality_plot = great_locality.sort_values(by='ad_count').tail(10)
locality_plot.sort_values(by='meter_mean').plot(x='locality_name', y='meter_mean', kind='barh', figsize=(8,6), legend=False)
plt.xlabel('Средняя цена кв м')
plt.ylabel('Населенный пункт')
plt.title('Стоимость недвижимости в 10 крупнейших населённых пунктах по количеству объявлений\n')
plt.show()

# %% [markdown]
# Рассмотрим медианную цену квартиры в населённых пунктах. И выведем населённые пункты с наиболее доступным и наиболее дорогим жильём.

# %%
locality_price = data.pivot_table(index = ['locality_name'], values = 'last_price', aggfunc = ['count', 'median'])
locality_price.columns = ['ad_count', 'price']
locality_price = locality_price.reset_index(drop=False)
locality_price.sort_values(by='price', ascending=False)
# Out:
#        locality_name  ad_count       price
# 269         Хязельки         1  11000000.0
# 16               Бор         2  10397600.0
# 1    Александровская         2   8725000.0
# 207  Санкт-Петербург     13632   5300000.0
# 221       Сестрорецк       163   5250000.0
# ..               ...       ...         ...
# 36          Выскатка         2    585000.0
# 212            Свирь         2    575000.0
# 226        Совхозный         2    517500.0
# 23      Вахнова Кара         1    450000.0
# 234       Старополье         3    450000.0
#
# [281 rows x 3 columns]

# %% [markdown]
# Рассмотрим медианную цену квадратного метра в населённых пунктах. И выведем населённые пункты с наиболее доступным и наиболее дорогим жильём.

# %%
median_locality = data.pivot_table(index = ['locality_name'], values = 'price_per_meter', aggfunc = ['count', 'median'])
median_locality.columns = ['ad_count', 'meter_median']
median_locality = median_locality.reset_index(drop=False)
median_locality.sort_values(by='meter_median', ascending=True)
# Out:
#        locality_name  ad_count   meter_median
# 234       Старополье         3   11000.000000
# 212            Свирь         2   11481.481481
# 23      Вахнова Кара         1   11688.311688
# 36          Выскатка         2   12335.480902
# 226        Совхозный         2   12629.129129
# ..               ...       ...            ...
# 110         Левашово         1   96997.690531
# 188           Пушкин       307   97938.144330
# 221       Сестрорецк       163   98341.232227
# 62       Зеленогорск        21  100000.000000
# 207  Санкт-Петербург     13632  103062.645671
#
# [281 rows x 3 columns]

# %% [markdown]
# Самая большая и самая маленькая цена за метр соответственно:

# %%
display(data.pivot_table(index = ['locality_name'], values = 'price_per_meter', aggfunc = 'max').sort_values(by='price_per_meter', ascending=False).head(1))

display(data.pivot_table(index = ['locality_name'], values = 'price_per_meter', aggfunc = 'min').sort_values(by='price_per_meter', ascending=False).head(1))
# Out:
#                  price_per_meter
# locality_name
# Санкт-Петербург        1907500.0
#                price_per_meter
# locality_name
# Левашово          96997.690531

# %% [markdown]
# Рассмотрим зависимость средней цены квартиры в зависимости от года публикации объявления:

# %%
y_data = data.pivot_table(index = ['year'], values = 'price_per_meter', aggfunc = 'mean')

y_data.plot(grid=True, figsize=(12, 5), style='o-')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Для Санкт-Петербурга рассмотрим зависимость средней цены метра в зависимости от удалённости от центра:

# %%
spb_db = data.loc[data['locality_name'] == 'Санкт-Петербург']
spb_distance = spb_db.pivot_table(index = ['cityCenters_nearest'], values = 'price_per_meter', aggfunc = 'mean')
spb_distance.sort_values(by='cityCenters_nearest', ascending=True).plot(grid=True, figsize=(12, 5), style='o-')
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest'>

# %% [markdown]
# По графику видно зависимость снижения цены квадратного метра в зависимости от удалённости от центра. На графике присутствуют два пика, которые скорее всего являются случаюностью - выбросом.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера</b></font>
#
# Хорошие графики и выводы
#
# </div>

# %% [markdown]
# Для Санкт-Петербурга рассмотрим зависимость средней цены метра общей площади:

# %%
spb_area = spb_db.pivot_table(index = ['total_area'], values = 'price_per_meter', aggfunc = 'mean').reset_index(drop=False)
spb_area.plot(x='total_area', y='price_per_meter', xlim=(12, 500), ylim=(30000, 650000), grid=True, figsize=(15, 5), style='-')
plt.show()

# %%
spb_area = spb_db.pivot_table(index = ['total_area'], values = 'price_per_meter', aggfunc = 'mean').reset_index(drop=False)
spb_area.plot(x='total_area', y='price_per_meter', xlim=(12, 500), ylim=(30000, 650000), grid=True, figsize=(15, 5), style='-')
plt.show()

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Здесь линейная диаграмма не очень подходит. Ее чаще используют для отображения динамики, как с годом продажи. А здесь она только усложняет восприятие. Лучше использовать диаграмму рассеивания.
# </div>
#
# <div class="alert alert-info"> <b>Мои комментарии:</b> Тут очень хотелось использовать именно график, а не диаграмму рассеивания. "Расчёска" тоже очень не нравится. Подскажи пожалуйста можно ли тут сгладить график? Или вывесли сглаженную более жирную кривую поверх?
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <font size='4'><b>👍 Комментарий ревьюера 2</b></font>
#
# Сгладить график можно, но ты придешь тогда к неправильным выводам: не будут видны изменения данных, выбросы. Сейчас из графика кажется, что чем выше площадь, тем выше разброс цен. А вот если нарисовать диаграмму рассеивания (ниже), то видно, что причина в том, что это скорее всего выбросы, отсюда и такие перепады
#
# </div>

# %%
# код ревьюера

plt.figure(figsize=(12, 6))
sns.scatterplot(data = spb_db, x='total_area', y='price_per_meter', alpha=0.4, s=30)
plt.title('Зависимость цены от площади')
plt.xlabel('Пллощадь квартир')
plt.ylabel('Цена кв м');

# %% [markdown]
# Для Санкт-Петербурга рассмотрим зависимость средней цены метра от площади кухни:

# %%
spb_kitchen = spb_db.pivot_table(index = ['kitchen_area'], values = 'price_per_meter', aggfunc = 'mean').reset_index(drop=False)
spb_kitchen.plot(x='kitchen_area', y='price_per_meter', xlim=(1, 110), ylim=(50000, 860000), grid=True, figsize=(15, 5), style='-')
plt.show()

# %% [markdown]
# По данному графику можно заметить, что влияние размера кухни на стоимость квадратного метра не значительное, хотя оно есть. При размере кухни от 0 до 8 цена немного уменьшается. От 8 до 40 увеличивается. Далее данные редкие и возможно на них не стоит опираться.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В ходе проекта определены населённые пункты с наиболее дорогим и с наиболее доступным жильём. Определена средняя цена квадратного метра для каждого населённого пункта.
# Рассмотрены иные факторы влияющие на цену квартиры.
# Для больших городов является актуальным рассматривать фактор удалённости жилья от центра.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <font size='4'><b>💡 Комментарий ревьюера</b></font>
#
# Удобно, когда общий вывод чуть подробнее. Можно вынести в него ключевые наблюдения
# </div>

# %% [markdown]
# <div style="border: 5px solid dodgerblue; padding: 15px">
#
# <font size='4'><b>Общий комментарий</b></font>
#
# Юля, спасибо за проект! Видно, что ты старалась и проделала большую самостоятельную работу. Проект получился очень качественным!
#
# Есть совсем немного доработок – надеюсь, тебе будет понятно, почему я оставила те или иные комментарии. Если у тебя есть какие-то вопросы, то с радостью на них отвечу.
#
# Буду ждать твою работу на повторное ревью!
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
