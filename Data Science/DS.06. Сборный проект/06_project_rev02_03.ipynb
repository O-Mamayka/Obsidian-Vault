# %% [markdown]
# Привет Юлия!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике (Клиника «Кивач», www.kivach.ru, республика Карелия). Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что в следующий раз можно сделать по-другому. "Жёлтые" комментарии не требуют твоих правок в проекте и их наличие НИКАК не повлияет на результат моей проверки. Но я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет.
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# # Анализ игровых платформ Xbox и PlayStation

# %% [markdown]
# # Описание проекта
# К рассмотрению представлен интернет-магазин «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные до 2016 года о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Необходимо выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
# # Описание данных
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.
#
# # 1. [Открытие файл с данными и изучение общей информации](#id1)
# Путь к файлу: /datasets/games.csv.
# # 2. [Подготовка данных](#id2)
# * Заменить названия столбцов (привести к нижнему регистру);
# * Преобразовать данных в нужные типы. Описать, в каких столбцах заменили тип данных и почему;
# * Обработать пропусков при необходимости: объяснить, почему заполнили пропуски определённым образом или почему не стали это делать; описать причины, которые могли привести к пропускам;
# * Обратить внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разобрать это значение и описать, как его обработать;
# * Посчитать суммарные продажи во всех регионах и записать их в отдельный столбец.
#
# # 3. [Провести исследовательский анализ данных](#id3)
# * Посмотреть, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# * Посмотреть, как менялись продажи по платформам. Выбрать платформы с наибольшими суммарными продажами и построить распределение по годам.
# * За какой характерный срок появляются новые и исчезают старые платформы?
# * Взять данные за соответствующий актуальный период. Актуальный период определить самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.
# * Какие платформы лидируют по продажам, растут или падают? Выберать несколько потенциально прибыльных платформ.
# * Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описать результат.
# * Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
# * Построить диаграмму рассеяния и посчитать корреляцию между отзывами и продажами. Сформулировать выводы.
# * Соотнести выводы с продажами игр на других платформах.
# * Посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# # 4. [Составить портрет пользователя каждого региона](#id4)
# Определить для пользователя каждого региона (NA, EU, JP):
# * Самые популярные платформы (топ-5). Описать различия в долях продаж.
# * Самые популярные жанры (топ-5). Пояснить разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# # 5. [Проверить гипотезы](#id5)
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задать самостоятельно пороговое значение alpha.
# Пояснить:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.
#
# # 6. [Написать общий вывод](#id6)

# %% [markdown]
# <a id="id1"></a>
# # 1. Открытие файл с данными и изучение общей информации

# %%
# вызов библиотеки pandas
import pandas as pd
# импорт библиотеки matplotlib
import matplotlib.pyplot as plt
# импорт библиотеки numpy
import numpy as np
# импорт библиотеки seaborn
import seaborn as sns
# импорт библиотеки scipy
import scipy
from scipy import stats as st
# импорт библиотеки warnings
import warnings

# %%
# чтение файла
try:
    games = pd.read_csv(r'c:\\Users\\Юки\\AnaliticData\\1_СБОРНЫЙ_ПРОЕКТ\\games.csv') #, sep='\t')
except:
    games = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь хорошо! При такой загрузке данных и тебе комфортно работать с проектом на домашнем ПК и у меня всё ОК во время проверки проекта в Юпитер Хабе</div>

# %%
# вывод на экран датасета
games.sample(5)
# Out:
#                                                     Name Platform  \
# 9285                Scene It? Bright Lights! Big Screen!     X360
# 14983                                     Beyblade Burst      3DS
# 15582                                    Crysis: Warhead       PC
# 2655   UFC Personal Trainer: The Ultimate Fitness System     X360
# 6358                                    Magical Vacation      GBA
#
#        Year_of_Release         Genre  NA_sales  EU_sales  JP_sales  \
# 9285            2009.0          Misc      0.12      0.00      0.00
# 14983           2016.0  Role-Playing      0.00      0.00      0.03
# 15582           2008.0       Shooter      0.00      0.02      0.00
# 2655            2011.0        Sports      0.53      0.18      0.00
# 6358            2001.0  Role-Playing      0.00      0.00      0.26
#
#        Other_sales  Critic_Score User_Score Rating
# 9285          0.01           NaN        NaN    NaN
# 14983         0.00           NaN        NaN    NaN
# ...

# %%
# просмотр общей информации о датасете
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводить весь датафрейм можно, но как правило я так не делаю (пространство на мониторе конЕчно, особенно когда в нескольких ячейках необходимо последовательно посмотреть, что в датафрейме изменилось). Достаточно "типового" .head() с 5 строками - как подтверждение того, что данные в датафрейм загружены верно. Если же в твоём случае считать, что 5 строк в начале и 5 строк в конце - это как массив из которого будет видно какие проблемы есть с данными (пропуски, аномальные значения), то поверь, для датафрейма с 16+ тысячами записей 10 строк это "капля в море". Проблемы с данными видны не будут. Для анализа мы будем использовать другие инструменты: .info(), .describe() и т.д.
#
# Если же ты выводишь датафрейм "полностью" для того, чтобы размерность датафрейма была на экране, то "красивее" использовать .shape в отдельной ячейке.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# вывод на экран датасета командой **display(games)** совершен умышленно - с целью рассмотения 5 строк в начале и 5 строк в конце - для выявления возможных артефактов.
# !Внесено изменение - с целью "поддержания идеи" и корректного вывода, использован метод sample()
#
# </div>

# %%
games_isnull_Value = games.isnull().sum().sort_values(ascending = False)
games_isnull_Percent = round(games.isnull().mean().sort_values(ascending = False)*100,2)
games_isnull = pd.concat([games_isnull_Value, games_isnull_Percent], axis=1, keys=['Пропущенные значения', 'Процент'])
games_isnull
# Out:
#                  Пропущенные значения  Процент
# Critic_Score                     8578    51.32
# Rating                           6766    40.48
# User_Score                       6701    40.09
# Year_of_Release                   269     1.61
# Name                                2     0.01
# Genre                               2     0.01
# Platform                            0     0.00
# NA_sales                            0     0.00
# EU_sales                            0     0.00
# JP_sales                            0     0.00
# Other_sales                         0     0.00

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Это хорошо! "Отображение" пропусков в процентах воспринимается проще и нагляднее, чем в абсолютных единицах.</div>

# %% [markdown]
# **Вывод:**
# * Загруженный датафрейм содержит 16715 наблюдений и 11 признаков;
# * 6 признака числовые, остальные 5 - категориальные, однако у некоторых признаков необходимо изменить тип: столбец User_Score содержит числовые данные, а столбец Year_of_Release - информацию о дате;
# * в таблице почти нет пропусков данных в данных о названиях платформ, игр, жанров и продажах, небольшое количество пропусков в годах выпуска и достаточно много пропусков в столбцах оценок и рейтинга - возможно, эти пропуски не случайны;
# * названия столбцов кажутся правильными, но требуют приведению к нижнему регистру.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Спасибо за точный и конкретный вывод по предварительному анализу загруженных данных. Зачастую коллеги ограничиваются исключительно кодом, без слов. Ввиду чего непонятно к каким выводам они пришли и что собираются делать дальше.</div>

# %% [markdown]
# <a id="id2"></a>
# # 2. Подготовка данных

# %% [markdown]
# **Переименование столбцов, перевод названий в нижний регистр**

# %%
games.columns = games.columns.str.lower()
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# **Обработаем пропуски**

# %%
# посмотрим на строки с пропущенными значениями в именах игр
games[games['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
print('Количество строк до удаления: ',games.shape[0])
# Out:
# Количество строк до удаления:  16715

# %% [markdown]
# Пропуски в столбце **name** соответствуют отсутствующим значениям столбца **genre** - скорее всего связано с техническим сбоем, ввиду малого количества - удалим данные строки.

# %%
games = games.dropna(subset=['name'])

# %%
print('Количество строк после удаления: ',games.shape[0])
# Out:
# Количество строк после удаления:  16713

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Молодец! Правильный вывод! И порядок действий правильный - вначале посмотреть на данные, а уже потом принимать решение.</div>

# %%
# c помощью библиотеки seaborn построим тепловую карту для визуализации данных
sns.set(rc={'figure.figsize':(20,8)})
sns.heatmap(games.isnull(), cmap=sns.color_palette(['#000099', '#ffff00']))
# Оформление графика
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.figtext(0.25, 0.03, "Рисунок 1. - Матрица пропущенных значений набора данных", fontsize=20)
plt.show()

# %% [markdown]
# Исходя из визуализации можем отметить:
# * пропуски значений в столбце **дата выпуска** единичны (1.6%), удаляя строки с пропущенными значениями по данному признаку - не потеряем ценной информации;
# * основная часть пропущенных данных содержится  в столбцах оценок и рейтинга;
# * пропуски соответствуют отсутствующим значениям почти для всех строк в столбцах оценок и рейтинга - удалять строки с отсутствующими в них значениями не будем.
# Видимо выборка содержит неоцененные по определенным причинам игры, в связи с чем пропуски  не случайны.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, проведена работа по анализу пропусков, в принципе высказан ряд корректных предположений на тему природы пропусков в оценках игр и пропусков в рейтингах.</div>

# %%
games[games['year_of_release'].isnull()]#.sort_values(by='na_sales', ascending=False)
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %%
#сохраним строки с пропущенными значениями в датафрейм games_isnull,
#к которому всегда сможем обратиться в случае необходимости
games_isnull = games[games['year_of_release'].isnull()]
games_isnull.head()
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 183             Madden NFL 2004      PS2              NaN    Sports      4.26
# 377            FIFA Soccer 2004      PS2              NaN    Sports      0.59
# 456  LEGO Batman: The Videogame      Wii              NaN    Action      1.80
# 475  wwe Smackdown vs. Raw 2006      PS2              NaN  Fighting      1.57
# 609              Space Invaders     2600              NaN   Shooter      2.36
#
#      eu_sales  jp_sales  other_sales  critic_score user_score rating
# 183      0.26      0.01         0.71          94.0        8.5      E
# 377      2.36      0.04         0.51          84.0        6.4      E
# 456      0.97      0.00         0.29          74.0        7.9   E10+
# 475      1.02      0.00         0.41           NaN        NaN    NaN
# 609      0.14      0.00         0.03           NaN        NaN    NaN

# %%
print('Количество строк до удаления: ',games.shape[0])
# Out:
# Количество строк до удаления:  16713

# %%
# удалим строки с пропущенными значениями по столбцу year_of_release
games = games.dropna(subset=['year_of_release']).reset_index(drop=True)

# %%
print('Количество строк после удаления: ',games.shape[0])
# Out:
# Количество строк после удаления:  16444

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Перед удалением, операцией по сути деструктивной, я бы рекомендовал посмотреть на записи с пропусками в соответствующих колонках, по отдельности (может эти записи по 100 млн. продаж принесли). 269 записей с пропусками в годе выпуска вроде немного, но ты учитывай тот факт, что все задачи в это проекте так или иначе связаны как раз с годом выпуска ... "В жизни" лишний взгляд на данные лишним не бывает.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# И ещё небольшой, но жизненный совет: **перед** и **сразу после** удаления строк (и для столбцов тоже будет верно) примени метод .shape к датафрейму. В этом случае наглядно будет видно сколько строк/столбцов было удалено. В некоторых ситуациях может быть ошибка в коде из-за которой удаляется больше чем ожидалось. Но этот способ поможет тебе такую проблему сразу обнаружить.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# (Немного рассуждений): да, всего 2 записи (из 16 тысяч) с пропусками в жанрах и названиях (плюс в этих же записях нет ни оценок пользователей, ни оценок критиков, ни рейтингов) и 269 записей (менее 2% из 16+ тысяч) с пропусками в годах выпуска. Казалось бы, надо удалять даже не раздумывая … но единого сценария нет на самом деле. С одной стороны - да, говорят, что "данных много не бывает", удалять записи из-за пропусков, когда датасет измеряется всего лишь сотнями-тысячами записей ой как не хочется.
#
# С другой стороны, если запись не спасти, если в ней несколько полей не заполнено или не заполнены ключевые поля, и ты чувствуешь, что заполнение их медианами/средними приведёт к смещению статистик - надо удалять. Да, можно поставить "заглушку", но тогда надо отдавать отчёт, что во всем последующем коде про эту "заглушку" помнить придётся. Т.е. перед построением всех графиков, гистограмм заглушку надо будет удалить. Перед расчетом корреляций - заглушку надо будет удалить. Перед проверкой гипотез заглушку надо будет удалить.
#
# Я бы так определил способ решения такой задачи: если записи с пропусками в ключевых для моего анализа полях составляют 1-3-5-до 10% строк, то я бы их из оригинального датафрейма вырезал (но сохранил бы в некий df, к которому при необходимости мог бы обратиться).
#
# А вообще, в таких случаях, когда нужно решить - заполнять пропуски или удалять строки с ними из df - всегда ищи эксперта в предметной области и советуйся с ним. Как правило это человек из бизнеса, который значит суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# Рекомедации учтены:
# - перед и после удаления применен метод .shape - для контроля количества удаленных строк;
# - сохранены записи с пропусками в столбце **year_of_release** в датафрейме games_isnull
# </div>

# %%
# просмотр уникальных значений столбца пользовательских оценок
print(games['user_score'].unique())
# Out:
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
#  '1.8' '3.8' '0' '1.6' '9.6' '2.4' '1.7' '1.1' '0.3' '1.5' '0.7' '1.2'
#  '2.3' '0.5' '1.3' '0.2' '0.6' '1.4' '0.9' '1' '9.7']

# %%
# просмотр уникальных значений столбца оценок критиков
print(games['critic_score'].unique())
# Out:
# [76. nan 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
#  70. 59. 64. 75. 60. 63. 69. 50. 25. 42. 44. 55. 48. 57. 29. 47. 65. 54.
#  20. 53. 37. 38. 33. 52. 30. 32. 43. 45. 51. 40. 46. 39. 34. 41. 36. 31.
#  27. 35. 26. 19. 28. 23. 24. 21. 17. 13.]

# %%
# просмотр уникальных значений столбца рейтинга
print(games['rating'].unique())
# Out:
# ['E' nan 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']

# %%
# осуществим замену пропущенных значений в столбцах critic_score, user_score,rating на пустые значения:
games['critic_score']=games['critic_score'].fillna(150)
games['user_score']=games['user_score'].fillna(150)
games['rating']=games['rating'].fillna('')

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, принято правильное решение! «Заглушка» (пусть и такая странная )))) для NaN значений в столбце ‘rating’ – это верное решение в этом проекте. Далее, когда ты будешь анализировать особенности регионов в зависимости от рейтинга ESRB, то увидишь, что если бы они остались NaN, то на графиках их не было бы видно, также такие игры "выпали" бы из анализа и выводов, а это красная ошибка в этом проекте.</div>

# %%
games.isnull().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# После проведенных операций выборка не содержит пропуски.

# %% [markdown]
# **Преобразуем данных в нужные типы:**

# %%
games['year_of_release'] = games['year_of_release'].astype('int')
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77         150.0        150
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00         150.0        150

# %%
# преобразуем значения столбца "год выпуска" в тип datetime
games['year_of_release']=pd.to_datetime(games['year_of_release'], format='%Y').dt.year
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77         150.0        150
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00         150.0        150

# %%
# рассмотрим содержание столбца user_score
games['user_score'].unique()
# Out:
# array(['8', 150, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# **tbd** - аббревиатура расшифровывается очень просто - To Be Determined, то есть "Будет определено". Таким образом строки, содержащие аббревиатуру tbd фактически имеют нулевые/пропущеныые значания. Выполним преобразование признака **user_score** в тип float, при этом зададим условие преобразования некорректного значения в NAN, а далее заменим пропуски на пустые значения.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты tbd меняешь на NaN - это правильно. По сути это и есть пропуски (строки с играми, для которых оценка не проставлена, пропущена по каким-то причинам).</div>

# %%
games[games['user_score']=='tbd'].head()
# Out:
#                                name platform  year_of_release   genre  \
# 119                   Zumba Fitness      Wii             2010  Sports
# 300  Namco Museum: 50th Anniversary      PS2             2005    Misc
# 516                 Zumba Fitness 2      Wii             2011  Sports
# 639                    uDraw Studio      Wii             2010    Misc
# 709                 Just Dance Kids      Wii             2010    Misc
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# 119      3.45      2.59       0.0         0.66         150.0        tbd      E
# 300      2.08      1.35       0.0         0.54          61.0        tbd   E10+
# 516      1.51      1.03       0.0         0.27         150.0        tbd      T
# 639      1.65      0.57       0.0         0.20          71.0        tbd      E
# 709      1.52      0.54       0.0         0.18         150.0        tbd      E

# %%
games['user_score']=pd.to_numeric(games['user_score'], errors='coerce')
games['user_score']=games['user_score'].fillna(150)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  float64
#  9   user_score       16444 non-null  float64
#  10  rating           16444 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты в 'critic_score' и 'user_score' (после обращения tbd в NaN) оставляешь NaN'ы без обработки - значительно упростит тебе жизнь дальше. В этом проекте - это верное решение.</div>

# %%
# проверим наличие дубликатов
games[games.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %%
# проверим наличие в выборке дубликатов по признакам name и platform:
games[games.duplicated(subset=['name','platform'], keep=False)].sort_values(by='name')
#games[games[['name','platform']].duplicated(keep=False)].sort_values(by='name')
# Out:
#                               name platform  year_of_release   genre  \
# 600                  Madden NFL 13      PS3             2012  Sports
# 15969                Madden NFL 13      PS3             2012  Sports
# 1177   Need for Speed: Most Wanted     X360             2012  Racing
# 1574   Need for Speed: Most Wanted     X360             2005  Racing
# 5883   Need for Speed: Most Wanted       PC             2005  Racing
# 11534  Need for Speed: Most Wanted       PC             2012  Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 600        2.11      0.22      0.00         0.23          83.0         5.5
# 15969      0.00      0.01      0.00         0.00          83.0         5.5
# 1177       0.62      0.78      0.01         0.15          83.0         8.5
# 1574       1.00      0.13      0.02         0.10          83.0         8.5
# 5883       0.02      0.23      0.00         0.04          82.0         8.5
# ...

# %% [markdown]
# Среди пары признаков "название игры - платформа" выявлены 3 пары дубликатов, две из которых не являются дублями так как имеют отличие по году выпуска, то есть являются обновлениями, выпущенных ранее игр. Игра "Madden NFL 13" действительно задублирована в датафрейме - сложим продажи по данным строкам и удалим дубликат:

# %%
# проверим наличие в выборке дубликатов по признакам name и platform, year_of_release, genre:
games[games.duplicated(subset=['name','platform','year_of_release', 'genre'], keep=False)].sort_values(by='name')
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 600    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 15969  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 600         0.0         0.23          83.0         5.5      E
# 15969       0.0         0.00          83.0         5.5      E

# %%
#games.loc[600, 'eu_sales':'other_sales'] = games.loc[[600,15969], 'eu_sales':'other_sales'].sum(axis=0)
#games.iloc[[600]]

rows = games.duplicated(subset=['name','platform','year_of_release', 'genre'], keep=False)

games.loc[rows, 'na_sales'] = games.loc[rows, 'na_sales'].sum()
games.loc[rows, 'eu_sales'] = games.loc[rows, 'eu_sales'].sum()
games.loc[rows, 'jp_sales'] = games.loc[rows, 'jp_sales'].sum()
games.loc[rows, 'other_sales'] = games.loc[rows, 'other_sales'].sum()

games[games.duplicated(subset=['name','platform','year_of_release', 'genre'], keep=False)]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 600    Madden NFL 13      PS3             2012  Sports      2.11      0.23
# 15969  Madden NFL 13      PS3             2012  Sports      2.11      0.23
#
#        jp_sales  other_sales  critic_score  user_score rating
# 600         0.0         0.23          83.0         5.5      E
# 15969       0.0         0.23          83.0         5.5      E

# %%
print('Количество строк до удаления',games.shape[0])
# Out:
# Количество строк до удаления 16444

# %%
games.drop_duplicates(subset=['name','platform','year_of_release', 'genre'], inplace = True)
games.reset_index(drop=True)
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16438  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16439               LMA Manager 2007     X360             2006        Sports
# 16440        Haitaka no Psychedelica      PSV             2016     Adventure
# 16441               Spirits & Spells      GBA             2003      Platform
# 16442            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
print('Количество строк после удаления',games.shape[0])
# Out:
# Количество строк после удаления 16443

# %%
# повторно проверим наличие в выборке дубликатов по признакам name и platform, year_of_release, genre:
games[games.duplicated(subset=['name','platform','year_of_release', 'genre'], keep=False)].sort_values(by='name')
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# <div class="alert alert-warning">
# <b>Предложение 👉</b>
#
# **games[games.duplicated()]** не означает, что в данных нет дубликатов (записей).
#
# В реальных рабочих датасетах скорее всего не будет полных дубликатов, но вот неявные наверняка будут встречаться, соответственно с ними надо будет уметь работать. Попробуй найти неявные дубликаты (нужно использовать параметр **subset**). Ну а в нашем учебном проекте пробуй найти дубликаты для пары "Имя - Игровая консоль".
#
# Как их планируешь и планируешь ли обрабатывать?</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# поиск неявных дубликов среди пары признаков "название игры - платформа" позволил выявить пару дублирующих строк, в результете было принято решение об объединение продаж и удаление дубликата:
# произведенное объединение строк не автоматизировано, т.е. при большом кол-ве дубликатов применить не удасться, в связи с чем - необходимо - прошу подсказать как можно усовершенствовать подход
#
# </div>

# %% [markdown]
# **Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец**

# %%
#games['total_sales']=games[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
games['total_sales'] = games.loc[: , 'na_sales':'other_sales'].sum(axis=1)
#games['total_sales']=games['na_sales']+games['eu_sales']+games['jp_sales']+games['other_sales']

display(games)
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16439  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16440               LMA Manager 2007     X360             2006        Sports
# 16441        Haitaka no Psychedelica      PSV             2016     Adventure
# 16442               Spirits & Spells      GBA             2003      Platform
# 16443            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь отлично более чем отлично ))) Не все это знают (обычно для "сложения" столбцов коллеги знаком ""+" оперируют).</div>

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16443
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     16443 non-null  float64
#  9   user_score       16443 non-null  float64
#  10  rating           16443 non-null  object
#  11  total_sales      16443 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# **Вывод:**
# 1. все пропуски обработаны - удалены строки с пропущенными значениями в столбцах **name** и **genre** (2 строки), а также в столбце **year_of_release** (269 строк - 1.6 % датасета).
# Удаление строк с пропущенными значениями в столбцах рейтинга и оценок пользователей и критиков не было выполнено, т.к. данные пропущенны не случайно - при обработке зависимостей в вышеназванных столбцах данный факт будет учтен.
# 2. Названия стобцов переведены в нижний регистр.
# 3. Изменен тип данных в столбецах **User_Score** и **Year_of_Release**.
# 4. Заменили значение **tbd** в столбце **user_score** на nan, затем применили «заглушку» для дальнейшего корректного исследования.
# 5. Посчитали суммарные продажи во всех регионах и записали их в столбец **total_sales**

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Теперь можно приступать собственно к анализу данных и ответам на вопросы проекта.</div>

# %% [markdown]
# <a id="id3"></a>
# # 3. Исследовательский анализ данных

# %% [markdown]
# 1. Посмотрим, сколько игр выпускалось в разные годы.

# %%
#Подсчет количества выпускаемых игр в разные годы
games.groupby('year_of_release')['name'].count()
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     652
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Агрегация по count() покажет нам число игр, выпущенных на всех платформах, в разрезе лет. Т.е. если одна и та же игра (name) вышла в некоем году на одной платформе, агрегат == 1. Если на 2-х платформах, агрегат == 2, ну и так далее. У меня вопрос к тебе – что в твоем случае, в написанном тобой коде мы считаем выпуском игры (в этом, некоем году)?
#
# Возможно, чтобы получить истинное количество «игр по годам» нам следует поискать дубликаты (используя subset по (Годам - Названиям игр) и затем исключить из полного датафрейма все дубли за исключением одной, «первой», строки? Как ты считаешь?</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# целью данного кода является представление численного количества игр по года в не зависимости от платформ  (дубликаты были отработаны в предыдущем разделе), ниже представлена соответствующая визуализация
#
# </div>

# %% [markdown]
# Количество выпускаемых игр с 1980 (9 игр) по 2008 (1427 игр) увеличивалось, с 2009 (1426 игр) - пошло на спад, в 2016 количнство выпускаемых игр составило 502 штуки.

# %%
games.groupby('year_of_release').name.count().plot(kind='bar',figsize=(12,6))
plt.xlabel("Год", fontsize=10)
plt.ylabel('Количество игр по каждому году', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.figtext(0.35, -0.02, "Рисунок 2. - Выпуск игр по годам", fontsize=14)
plt.show()

# %% [markdown]
# **Вывод:** Диаграмма показывает, что начиная с 1980 г. ростет выпуск игр, максимальный значения по количеству достиглись в 2008-2099 гг (более 1400 игр в год), однако начиая с 2010 г. наблюдается спад в выпуске игр - это можно объяснить популярность игр в мобильных телефонах.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Просто супер: график подписан, оси подписаны. Не часто на самом деле такой скрупулёзный подход к оформлению встречается. Молодец! Также, здорово, что есть объяснение поведения данного графика. Пытаться понять полученный результат - важная часть работы аналитика.</div>

# %% [markdown]
# 2. Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам.

# %%
sales_group = games.groupby('platform')['total_sales'].sum().sort_values(ascending=False)[:10]
sales_group.plot(kind='bar',figsize=(16,4))

plt.xlabel("Наименование платформы", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.figtext(0.35, -0.1, "Рисунок 3. - Изменение продажи по платформам", fontsize=14)
plt.show()

sales_group = sales_group.reset_index(drop=False)
sales_group
favor_platform = sales_group['platform'].head(6)
favor_platform
# Out:
# 0     PS2
# 1    X360
# 2     PS3
# 3     Wii
# 4      DS
# 5      PS
# Name: platform, dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# **games.groupby('platform')['total_sales'].sum().sort_values(ascending=False)[:10]** - совсем немногие студенты делают выборку топ-Х платформ так как это делаешь ты, в коде. Процентов 80 формируют подобный list вручную. Молодец!</div>

# %%
#favor_platform = ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %% [markdown]
# **Вывод:** Распределение показывает, что лидерами рынка продаж являются платформы: PS2, X360, PS3, Wii, DS, PS. Максимальные суммарные продажи принесла платформа **PS2**

# %%
# рассмотрим жизненный цикл на примере патформ с наибольшими суммарными продажами

for i in range(len(favor_platform)):
    
    platforms = favor_platform[i]
    games.query('platform==@platforms').groupby('year_of_release')['total_sales'].sum().plot(
    kind='bar', grid=True,figsize=(16,4))
    plt.title(platforms) # присвоение заголовка гистограмме
    plt.xlabel("Год выпуска", fontsize=10)
    plt.ylabel('Суммарные продажи', fontsize=10)

    if i == len(favor_platform)-1 :
        plt.figtext(0.25, -0.14, "Рис.4 - Гистограмм суммарных продаж по годам для 6 самых популярных платформ")

    plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# 1. Здесь конечно, по сути, надо бы список с топ-6 платформами автоматизировано формировать. Ты только представь, что тебе нужно не 6, а скажем 150 значений указать, или в коде, в разных местах иметь разный топ-Х. Сделаешь?
#
# 2. И строить графики желательно в цикле.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# замечание учтено - графики построены в цикле.
# </div>

# %% [markdown]
# 3. Выявим за какой характерный срок появляются новые и исчезают старые платформы?

# %%
# посмотрим на распределение выпускаемых игр по годам с разбивкой по платформам по средством диаграммы рассеяния

color = np.array([.1, .6, .3])
games.plot(x='year_of_release', y='platform', kind='scatter',\
figsize=(16, 6), grid=True, alpha=0.5,c=color.reshape(1,-1))

plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Платформа', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.figtext(0.25, -0.02, "Рисунок 5. - Выпуск игр по годам с разбивкой по платформам", fontsize=14)
plt.show()

# %%
# посмотрим на распределение выпускаемых игр по годам с разбивкой по платформам по средством тепловой карты

sns.set(rc={'figure.figsize':(20,8)})
sns.heatmap(games.pivot_table(index='platform', columns='year_of_release',\
values='total_sales',aggfunc='sum'), center=350)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.figtext(0.22, -0.03, "Рисунок 6. - Распределение продаж по годам в разрезе платформ", fontsize=14)
# Out:
# Text(0.22, -0.03, 'Рисунок 6. - Распределение продаж по годам в разрезе платформ')

# %%
# посмотрим на распределение выпускаемых игр по годам с разбивкой по платформам по средством линейного графика

games.pivot_table(index='year_of_release', columns='platform', values='total_sales',aggfunc='sum').plot(
    figsize=(20,16), grid=True)

plt.figtext(0.4, 0.05, "Рис.7 -'Жизненный цикл' платформ", fontsize=14)
plt.xlabel("Год выпуска", fontsize=10)
plt.legend(loc=(0, 0.41), frameon=True, ncol=1,fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Код очень длинный (а PEP8 определяет длину строки в 79 символов) - попробуй длинные - переносить, а между строками использовать пустые строки. Ну и желательно код комментировать, хотя бы коротко (что делаешь и каков будет результат - так твоим коллегам будет проще за твоей мыслью следить). Этот комментарий может относиться к нескольким ячейкам этой «тетрадки».
#
# Хороший разработчик форматирует и комментирует свой код, тогда другие разработчики быстрее разберутся в программе. Это важно, ведь код чаще читают, чем пишут: напишет один, а прочтут — сотни или тысячи (если код хороший).
# «Пишите код так, как будто сопровождать его будет склонный к насилию психопат, который знает, где вы живете.» ©1991, John F. Woods, разработчик
#
# ---
# Давай обсудим стиль кодирования (программирования)? Смотри что сейчас происходит в этой ячейке (**возможно не всё применимо к твоему коду здесь, но я попытался вспомнить все часто встречающиеся недочёты**), что "режет" глаз и что можно сделать по-другому, чуть лучше:
#
# 1. Комментарии к строке кода: они должны располагаться выше соответствующей строки кода (выше строки к которой относятся) и должны быть от этой строки отделены пустой строкой. Если же они расположены справа, то для того чтобы увидеть, что там написано приходится пользоваться скроллиногом. Надо добиться того, чтобы ячейку не приходилось прокручивать, т.к. это не добавляет удобства ни при отладке кода, ни для понимания что в этой ячейке "происходит". Как альтернатива – комментарий может размещаться выше, в Markdown-ячейке.
#
# 2. Бывает, что встречаются очень длинные строки кода, которые также уходят за правый край ячейки. Такие строки должны разбиваться разделителем (вот таким: \\). Это best practice, требование PEP8, а именно: PEP8 определяет длину строки в 79 символов.
#
# 3. **В идеале**: одна ячейка - одна строка кода. Почему так? Да как минимум из соображения понятности: будучи выполненной, под этой ячейкой должен отображаться результат трансформации данных. Ты или твой коллега должны видеть, как поменялись данные после выполнения ячейки с кодом. Следующая ячейка - ещё строка кода и соответствующим output'ом. Будешь делать так - коллеги будут тебе благодарны за то, что легко будут следовать за твоей мыслью. И отладку это упрощает.
#
# Ну и как противоположность - можно в одну ячейку "положить" результат 3-х последовательных groupby + ещё чего-нибудь. Разобраться с ходу "что происходит" будет очень трудно, придётся всё равно код разносить по ячейкам и смотреть последовательно что происходит. Но ведь логично это делать удобным способом сразу, ведь так?
#
# 4. Неиспользуемые, закомментированные строки выше вынеси в другую ячейку, отдельную, выше. Можешь для удобства своего прокомментировать (на память). И оставь там это код, так, чтобы он не смешивался с рабочим кодом.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# замечание учтено - внесены корректировки, буду стараться придерживаться правил оформления.
# </div>

# %%
# на примере патформ с наибольшими суммарными продажами выявим время жизни платформ

favor_platform = ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']
year_life=[]
for platforms in favor_platform:
    platforms_diff = games.query('platform==@platforms')['year_of_release'].max()-\
    games.query('platform==@platforms')['year_of_release'].min()
    year_life.append(platforms_diff)
    print(platforms, platforms_diff)
    
mean = int(round((sum(year_life) / len(year_life)),0))
print('Среднее время жизни платформы: ',mean, 'лет.')
# Out:
# PS2 11
# X360 11
# PS3 10
# Wii 10
# DS 28
# PS 9
# Среднее время жизни платформы:  13 лет.

# %% [markdown]
# При подсчете продолжительности жизни у платформы DS выявлено время существования 28 лет, согласно дынным wikipedia: консоль была выпущена в 2004 году в Канаде, США и Японии, таким образом попавшие в выборку ранее указанной даты игры являются артифактами.

# %%
# рассмотрим игры, содержащиеся в датафрейме, выпущенные ранее 2004 года:
games.query('(platform=="DS") and (year_of_release < 2004)')
# Out:
#                                       name platform  year_of_release   genre  \
# 15704  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15704       0.0       0.0      0.02          0.0         150.0       150.0
#
#       rating  total_sales
# 15704                0.02

# %% [markdown]
# Выявлена одна игра сроком выпуска 1985 - явно являющаяся артефактом, так как данная позиция содержала прописки в оценках критиков и пользователей и не несет ценной информации - удалим из дальнейшего анализа

# %%
print('Количество строк до удаления',games.shape[0])
# Out:
# Количество строк до удаления 16443

# %%
games = games.drop(games.index[15704],axis=0).reset_index(drop=True)

# %%
print('Количество строк до удаления',games.shape[0])
# Out:
# Количество строк до удаления 16442

# %%
# повторно произведем расчет средней продолжительности жизни платформ

favor_platform = ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']
year_life=[]
for platforms in favor_platform:
    platforms_diff = games.query('platform==@platforms')['year_of_release'].max()-\
    games.query('platform==@platforms')['year_of_release'].min()
    year_life.append(platforms_diff)
    print(platforms, platforms_diff)
    
mean = int(round((sum(year_life) / len(year_life)),0))
print('Среднее время жизни платформы: ',mean, 'лет.')
# Out:
# PS2 11
# X360 11
# PS3 10
# Wii 10
# DS 9
# PS 9
# Среднее время жизни платформы:  10 лет.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **ds=games.query('platform=="DS"and year_of_release!=2045')** - откуда здесь 2045 год взялся?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# датафрейм не содержит данные по 2045 году - данный кусок кода является опечаткой и никак не влияет на результат выполнения
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Почему по твоим данным платформа DS уже 28 лет на рынке? Посмотри пожалуйста в Интернете когда она "появилась на свет"?
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# **Вывод:** платформы с наибольшими суммарными продажами набрали свою популярность с начала 2000-х., а период от первых продаж до исчезнования в среднем занял 10 лет.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **период от первых продаж до исчезнования в среднем занял 13 лет.** - цифра должна быть меньше.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# произведено подробное рассмотрение платформа DS - выявлен и удален артефакт. Повторно произведен расчет среднего периода жизни платформ, который составил 10 лет.
# </div>

# %% [markdown]
# 4. На осовании данных за соответствующий актуальный период определим какие платформы лидируют по продажам, растут или падают?

# %% [markdown]
# Исходя из визуализации, представленной на рисуноке 2 ("Выпуск игр по годам"), нормальным выглядит распределение продаж с 2001 по 2015 избавимся от выбросов и далее будем работать только с данным периодом,принимая его за актуальный период.
# Данные за 2016 не заполнены до конца, поэтому выберем платформы с ненулевыми продажами за 2016 год, чтобы работать с ними в дальнейшем.

# %%
# посмотрим на актуальные платформы 2016
games_2016=games[(games['year_of_release']==2016)&(games['total_sales']!=0)]
print('В 2016 существуют платформы:',games_2016['platform'].unique())
# Out:
# В 2016 существуют платформы: ['PS4' '3DS' 'XOne' 'WiiU' 'PS3' 'PC' 'X360' 'PSV' 'Wii']

# %% [markdown]
# Посмотрим выбросы с помощью Диаграмма рассеяния и Диаграммы размаха

# %%
games.sample(3)
# Out:
#                                  name platform  year_of_release   genre  \
# 15666             Exhibition Volume 6       XB             2004    Misc
# 12384  Santa Claus Is Comin' to Town!      Wii             2011  Puzzle
# 9894                     Phantom Dust       XB             2004  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15666      0.01      0.00       0.0          0.0         150.0       150.0
# 12384      0.06      0.00       0.0          0.0         150.0       150.0
# 9894       0.08      0.02       0.0          0.0          81.0         8.5
#
#       rating  total_sales
# 15666                0.01
# 12384      E         0.06
# 9894       T         0.10

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data = games, x='total_sales', y='year_of_release', alpha=0.4, s=30)
plt.title('продажи по годам')
plt.xlabel('Количество продаж')
plt.ylabel('Год');

# %%
# выявим выбросы:
games.boxplot(column=['total_sales'], figsize=(16,5), grid=True)
plt.figtext(0.33, 0.03, "Рис.8 - Диаграмма размаха суммарных продаж ", fontsize=14)
plt.show()

# %%
# и диаграмму размаха без выбросов:
plt.ylim(0.05, 0.5)
games.boxplot(column=['total_sales'], figsize=(16,5), grid=True)
plt.figtext(0.33, 0.03, "Рис.9 - Диаграмма размаха суммарных продаж ", fontsize=14)
plt.show()

# %% [markdown]
# Из данных графиков видно, что основное количество продаж по платформам от 50 до 500 тысяч экземпляров. Другие значения можно считать выбросами.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# График не говорящий, на нем ничего из-за выбросов не видно.
# </div>

# %%
# за выбросы примем значения продаж выше 40, отбрасываем выбросы 
games_filter = games[games['total_sales'] < 40]
# по гистограмме (рис.2) выбираем актуальный период с 2001 по 2015 
games_filter = games[(games['year_of_release'] > 2000) & (games['year_of_release'] <= 2016)]

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# **games_filter=games[(games['year_of_release'] > 2000) & (games['year_of_release'] < 2016)]** - Нет, здесь ты берешь для анализа слишком большой интервал.
#
# Для стремительно развивающейся игровой индустрии период > 3-4 лет — очень много. Внутри выбранного тобой периода произошли резкие изменения, например, произошла замена одного поколения консолей следующим (PS -> PS2 -> PS3 -> PS4). Некоторые платформы совсем исчезли (например, платформа DS не имеет новых релизов игр с 2013 года, PS2 с 2011 года, PSP с 2015 года). Как думаешь - помогут нам эти платформы построить прогноз на 2017 год или всё же лучше уменьшить интервал для анализа?
#
# Другими словами, в сфере электроники, в том числе и консолей, рынок быстро меняется то, что было актуально 5–10 лет назад сейчас уже не интересует потребителя. Например, можно было бы сделать вывод, что популярной останется платформа X360, но ее в 2016 году уже не выпускали, у PS3 поддержка закончилась так же в 2016 году. Nintendo WII и DS тоже не поддерживаются с 2013 года. Если наш «Стримчик» закупит игры для этих платформ, то явно в продажах 2017 года он от этого не выиграет.
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. В нашем случае думаю, что 3 года: 2014, 2015 и неполный 2016 - ОК.
#
# Когда изменишь "горизонт" анализа и перезапустишь код в этой "тетрадке" - посмотри, как поменяется этот и все последующие выводы.</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# То, что мы исключаем из актуального периода данные за 2016 год - серьёзная ошибка. Не брать данные продаж по платформам за 2016 год только потому, что он "не полный" - неправильно. В данных 2016 года находятся самые актуальные, текущего периода тренды. Они очень пригодятся нам, чтобы сделать качественный прогноз на 2017 год.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что результат запроса/’среза’ ты присваиваешь новому датафрейму. Таким образом оригинальный датафрейм ты оставляешь нетронутым, не перезаписываешь (вдруг нам опять понадобятся данные из него чуть ниже). Это верное решение. Best practice. Молодец!</div>

# %%
print('В выбранном актуальном периоде существуют платформы:\n',*games_filter['platform'].unique().astype('str'))
# Out:
# В выбранном актуальном периоде существуют платформы:
#  Wii DS X360 PS3 PS2 GBA PS4 3DS XB PC PSP XOne WiiU GC PS PSV GB N64 DC WS

# %% [markdown]
# Таким образом, при анализе данных с отсечкой за 2016 года, мы не пропускаем ни одну платформу ( в 2016 существуют платформы: PS4, 3DS, XOne, WiiU, PS3, PC, X360, PSV, Wii).

# %%
games_filter.groupby('platform').total_sales.sum().sort_values(ascending=False).plot(kind='bar',figsize=(18,4))
plt.xlabel("Платформа", fontsize=10)
plt.ylabel('Количество продаж', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.figtext(0.35, -0.1, "Рисунок 9. - Распределение продаж по платформам", fontsize=14)
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,8)})
sns.heatmap(games_filter.pivot_table(index='platform', columns='year_of_release', values='total_sales',aggfunc='sum'), center=150)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.figtext(0.22, -0.03, "Рисунок 10. - Распределение продаж по годам в разрезе платформ в актуальном периоде", fontsize=14)
# Out:
# Text(0.22, -0.03, 'Рисунок 10. - Распределение продаж по годам в разрезе платформ в актуальном периоде')

# %% [markdown]
# Визуализация показала, что в актуальном периоде лидирующие позиции по продажам по-преждему принадлежит платформе PS2, за ней следуют платформы X360, PS3, Wii, DS. Продажи по вышеназванным платформам падают - то есть компании достигли своего "пика" дохода/спроса и находятся в стадиях  зрелости, либо упадка.

# %% [markdown]
# 5. Выберем несколько потенциально прибыльных платформ.

# %% [markdown]
# Исключим из анализа ранее рассмотренные платформы (PS2, X360, PS3, Wii, DS, PS):

# %%
games_filter_prognoz = games_filter[(games_filter['platform']!='PS2')&(games_filter['platform']!='X360')&(games_filter['platform']!='PS3')&(games_filter['platform']!='Wii')&(games_filter['platform']!='DS')&(games_filter['platform']!='PS')]
platform_prognoz = games_filter_prognoz['platform'].unique()
print('Визуализируем распределения для платформ: \n', *platform_prognoz)
# Out:
# Визуализируем распределения для платформ:
#  GBA PS4 3DS XB PC PSP XOne WiiU GC PSV GB N64 DC WS

# %%
sns.set(rc={'figure.figsize':(20,8)})
sns.heatmap(games_filter_prognoz.pivot_table(index='platform', columns='year_of_release', values='total_sales',aggfunc='sum'), center=150)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.figtext(0.22, -0.03, "Рисунок 11. - Распределение продаж по годам в актуальном периоде для выбранных платформ", fontsize=14)
# Out:
# Text(0.22, -0.03, 'Рисунок 11. - Распределение продаж по годам в актуальном периоде для выбранных платформ')

# %%
games_filter_prognoz.query('platform==@platform_prognoz[0]').groupby('year_of_release').total_sales.sum().plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[0]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[1]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[1]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[2]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[2]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[3]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[3]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[4]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[4]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[5]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[5]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[6]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[6]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[7]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[7]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[8]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[8]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[9]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[9]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[10]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[10]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[11]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[11]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[12]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[12]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)
plt.show()
games_filter_prognoz.query('platform==@platform_prognoz[13]').pivot_table(index='year_of_release', values='total_sales',aggfunc='sum').plot(kind='bar', figsize=(10,5))
plt.title(platform_prognoz[13]) # присвоение заголовка гистограмме
plt.xlabel("Год выпуска", fontsize=10)
plt.ylabel('Суммарные продажи', fontsize=10)

plt.figtext(0.2, -0.1, "Рис.12 - Гистограмм суммарных продаж по годам для 6 самых популярных платформ")
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# 1. Вместо этого кода лучше использовать циклы.
#
# 2. Подпись к графику не верна - тут явно не 6 платформ.
#
# 3. Код очень длинный (а PEP8 определяет длину строки в 79 символов) - попробуй длинные - переносить, а между строками использовать пустые строки. Ну и желательно код комментировать, хотя бы коротко (что делаешь и каков будет результат - так твоим коллегам будет проще за твоей мыслью следить). Этот комментарий может относиться к нескольким ячейкам этой «тетрадки».
# </div>

# %% [markdown]
# **Вывод:** потенциально прибыльными платформами являются PS4 и XOne - рекомендуется в них инвестировать.

# %% [markdown]
# 6. Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам.

# %%
games_filter_prognoz.sort_values(by='total_sales', ascending = False)
# Out:
#                                 name platform  year_of_release         genre  \
# 25     Pokemon Ruby/Pokemon Sapphire      GBA             2002  Role-Playing
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 40                      Mario Kart 7      3DS             2011        Racing
# 42                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# 15875        Super Stardust Ultra VR      PS4             2016       Shooter
# 15874                 Puyo Pop Fever       GC             2004        Puzzle
# 15869              Shinobi Koutsutsu      PSP             2014     Adventure
# 15868           Guild Wars: Factions       PC             2006  Role-Playing
# 16441            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
games_filter_prognoz.boxplot(column='total_sales', by='platform',figsize=(30,10))
plt.show()

# %%
data_platforms = [games_filter_prognoz[games_filter_prognoz['platform'] == 'GBA']['total_sales'],games_filter_prognoz[games_filter_prognoz['platform'] == 'PS4']['total_sales'], games_filter_prognoz[games_filter_prognoz['platform'] == '3DS']['total_sales']]
plt.show()
#@platform_prognoz[0]     GBA PS4 3DS XB PC PSP XOne WiiU GC PSV GB N64 DC WS

# %%
sns.set(rc={'figure.figsize':(18,8)})
sns.boxplot(data=games_filter_prognoz, x = 'total_sales', y = 'platform',palette='rainbow', showfliers=False)#-для отсечки выбросов
plt.figtext(0.33, 0.03, "Рис.13 - Диаграмма размаха суммарных продаж в актуальном периоде в разрезе платформ", fontsize=14)
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# К сожалению, на этом графике **уверенно** сравнивать квартили (медиану, 25ый и 75ый) у части платформ не получается. Велика вероятность ошибки. Для более обоснованных выводов на основе **только графика** (иначе зачем такой **неговорящий график нужен**) нужно сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim
#
# То есть, я бы предложил после этого графика ещё один построить, в котором бы сами "ящики" были лучше видны. На том, что выше выбросы их фактически "забили". Попробуй использовать в параметре ylim, значение, которое ещё больше ограничит значение по OY "сверху" (например, ylim(0, 0.85). Ну и «строй» график большего размера (попробуй использовать: figsize=[20, 10].
#
# Ну а в твоем случае, из-за того, что на графике не разобрать квартили - для точного сравнения "ящиков" мы вынуждены будем использовать describe().</div>

# %%
games_filter_prognoz[games_filter_prognoz['platform']=='GB']
# Out:
#                                                     name platform  \
# 886                  The Legend of Zelda: Oracle of Ages       GB
# 918               The Legend of Zelda: Oracle of Seasons       GB
# 1019               Harry Potter and the Sorcerer's Stone       GB
# 1184                             Dragon Quest Monsters 2       GB
# 2301               Pokemon Card GB2: Here Comes Team GR!       GB
# 3540                            Hamtaro: Ham-Hams Unite!       GB
# 4863   From TV Animation One Piece: Yume no Lufy Kaiz...       GB
# 8903                             Star Ocean: Blue Sphere       GB
# 9715                Medarot 4: Kabuto / Kuwagata Version       GB
# 11664                                  Mega Man Xtreme 2       GB
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 886               2001        Action      0.92      0.53      0.41
# 918               2001     Adventure      0.87      0.52      0.41
# ...

# %% [markdown]
# **Вывод:** Продажи **XOne** и **PS4** сильно выделяются на фоне остальных-это мастодонты рынка. Также выделяются продажи по платформе **GB** - некоторые игры имели большой успех, но только в 2001 года, далее продаж по данной платформе не было. Стоит отметить большие выбросы в прождажах у платформ **GBA**, **PS4**, **3DS** - некоторые игры данных платформ пользовались огромным спросом.

# %% [markdown]
# 7. Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков:построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.

# %%
# посчитаем корреляцию между отзывами и продажами в общем случае
(games_filter_prognoz[['critic_score','user_score','na_sales','eu_sales','jp_sales','other_sales']].corr()
 .style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_cbe31_row0_col0, #T_cbe31_row1_col1, #T_cbe31_row2_col2, #T_cbe31_row3_col3, #T_cbe31_row4_col4, #T_cbe31_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cbe31_row0_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_cbe31_row0_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_cbe31_row0_col3, #T_cbe31_row0_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_cbe31_row0_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_cbe31_row1_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_cbe31_row1_col2, #T_cbe31_row1_col3, #T_cbe31_row1_col4, #T_cbe31_row1_col5, #T_cbe31_row2_col0, #T_cbe31_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cbe31_row2_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_cbe31_row2_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_cbe31_row2_col5 {
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Надо не в "общем случае", а для 2-3х конкретных платформ помимо PS4 (то, что делаешь ниже).</div>

# %%
# посчитаем корреляцию между отзывами и продажами для платформы PS4
(games_filter_prognoz.query('platform=="PS4"')[['critic_score','user_score','na_sales','eu_sales','jp_sales','other_sales']].corr().style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_c0e6d_row0_col0, #T_c0e6d_row1_col1, #T_c0e6d_row2_col2, #T_c0e6d_row3_col3, #T_c0e6d_row4_col4, #T_c0e6d_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c0e6d_row0_col1 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_c0e6d_row0_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c0e6d_row0_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c0e6d_row0_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_c0e6d_row0_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c0e6d_row1_col0 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_c0e6d_row1_col2, #T_c0e6d_row1_col3, #T_c0e6d_row1_col4, #T_c0e6d_row1_col5, #T_c0e6d_row3_col0, #T_c0e6d_row3_col1, #T_c0e6d_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c0e6d_row2_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c0e6d_row2_col1 {
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Если бы в 'user_score' и 'critic_score' мы оставили бы NaN (не заполняли «заглушкой» == 150), то .corr бы их при расчете корреляций не стал использовать (и мы получили бы коэффициенты для **реальных** оценок). Сейчас же своё влияние на значения коэффициентов корреляции имеют и искусственно сгенерированные нами оценки, за фактическую корректность которых мы ручаться совсем не можем.</div>

# %% [markdown]
# Линейная зависимость между оценками критиков и пользователей и продажами минимальна, либо взаимосвязь более сложная.

# %%
# построим диаграмму рассеяния для платформы 'PS4'
sns.set(rc={'figure.figsize':(18,6)})
critic_score_total_sales = sns.scatterplot(data=games_filter_prognoz.query('platform == "PS4"'), x="critic_score", y="total_sales",
    sizes=(20, 500), legend=False)
#critic_score_total_sales.axes.figtext("Диаграмма рассеяния оценок для платформы 'PS4'", fontsize=16)
critic_score_total_sales.set(xlim=(10, 100), ylim=(-0.5, 14))
critic_score_total_sales.set_xlabel("Оценка критиков", fontsize=14)
critic_score_total_sales.set_ylabel("Суммарные продажи", fontsize=14)
plt.show()

critic_score_total_sales = sns.scatterplot(data=games_filter_prognoz.query('platform == "PS4"'), x="user_score", y="total_sales",
    sizes=(20, 500), legend=False)
critic_score_total_sales.set(xlim=(1, 10), ylim=(-0.5, 14))
critic_score_total_sales.set_xlabel("Оценка пользователей", fontsize=14)
critic_score_total_sales.set_ylabel("Суммарные продажи", fontsize=14)
plt.figtext(0.35, 0.00, "Рис. 14- Диаграммы рассеяния оценок для платформы 'PS4'", fontsize=16)
plt.show()

# %% [markdown]
# **Вывод:** чем выше оценка, тем больше продаж, и не важно оценил игру пользователь или критик. А также самые дорогие продажи приходятся на самые высокие оценки критиков.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здорово! Ты понимаешь, что формулировать, что якобы коэффициент корреляции (Пирсона) между 2 переменными (в нашем случае между "total_sales" и "critic_score") есть показатель того, что **на количество продаж влияет оценка критиков** - неверно. А ведь примерно в 70% студенческих работ именно такое и встречается.
#
# Действительно, коэффициент свидетельствует **о наличии или отсутствии линейной связи** между переменными, и **измеряет выраженность** этой связи. Другими словами, коэффициент корреляции - это инструмент, с помощью которого можно проверить гипотезу о **линейной** зависимости и измерить степень этой зависимости.
#
# Например, в нашем случае, связь между продажами и оценками экспертов для всех платформ является **прямой, слабой** степени выраженности (во всех случаях коэффициент около 0,3-0,4).
#
# То есть, влияния оценок на продажи нет. Коэффициент корреляции Пирсона не про это. Он про линейную зависимость 2-х переменных. И ещё, это коэффициент **НЕ ОБЪЯСНЯЕТ** зависимость, он **НЕ ГОВОРИТ** почему наблюдается такой эффект, но просто констатирует факт, что корреляция наблюдается (например, "мы видим, что те игры, которым наши эксперты дают высокие оценки - продаются лучше". А вот почему они продаются лучше - можно только предполагать ... разные причины могут быть).</div>

# %% [markdown]
# 8. Соотнесем выводы с продажами игр на других платформах.

# %%
# посчитаем корреляцию между отзывами и продажами для платформы XOne
(games_filter_prognoz.query('platform=="XOne"')[['critic_score','user_score','na_sales','eu_sales','jp_sales','other_sales']].corr().style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_f7c8e_row0_col0, #T_f7c8e_row1_col1, #T_f7c8e_row2_col2, #T_f7c8e_row3_col3, #T_f7c8e_row4_col4, #T_f7c8e_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f7c8e_row0_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_f7c8e_row0_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f7c8e_row0_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f7c8e_row0_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f7c8e_row0_col5, #T_f7c8e_row4_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f7c8e_row1_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_f7c8e_row1_col2, #T_f7c8e_row1_col3, #T_f7c8e_row1_col4, #T_f7c8e_row1_col5, #T_f7c8e_row2_col0, #T_f7c8e_row2_col1, #T_f7c8e_row5_col0, #T_f7c8e_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f7c8e_row2_col3, #T_f7c8e_row3_col2 {
#   background-color: #ee8669;
# ...

# %%
# построим диаграмму рассеяния для платформы 'XOne'
sns.set(rc={'figure.figsize':(18,6)})
critic_score_total_sales = sns.scatterplot(data=games_filter_prognoz.query('platform == "XOne"'), x="critic_score", y="total_sales",
    sizes=(20, 500), legend=False)
#critic_score_total_sales.axes.figtext("Диаграмма рассеяния оценок для платформы 'PS4'", fontsize=16)
critic_score_total_sales.set(xlim=(10, 100), ylim=(-0.5, 14))
critic_score_total_sales.set_xlabel("Оценка критиков", fontsize=14)
critic_score_total_sales.set_ylabel("Суммарные продажи", fontsize=14)
plt.show()

critic_score_total_sales = sns.scatterplot(data=games_filter_prognoz.query('platform == "XOne"'), x="user_score", y="total_sales",
    sizes=(20, 500), legend=False)
critic_score_total_sales.set(xlim=(1, 10), ylim=(-0.5, 14))
critic_score_total_sales.set_xlabel("Оценка пользователей", fontsize=14)
critic_score_total_sales.set_ylabel("Суммарные продажи", fontsize=14)
plt.figtext(0.35, 0.00, "Рис.15 - Диаграммы рассеяния оценок для платформы 'PS4'", fontsize=16)
plt.show()

# %%
# посчитаем корреляцию между отзывами и продажами для платформы WiiU
(games_filter_prognoz.query('platform=="WiiU"')[['critic_score','user_score','na_sales','eu_sales','jp_sales','other_sales']].corr().style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_b580d_row0_col0, #T_b580d_row1_col1, #T_b580d_row2_col2, #T_b580d_row3_col3, #T_b580d_row4_col4, #T_b580d_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b580d_row0_col1 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_b580d_row0_col2, #T_b580d_row0_col5, #T_b580d_row2_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_b580d_row0_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b580d_row0_col4, #T_b580d_row5_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_b580d_row1_col0 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_b580d_row1_col2, #T_b580d_row1_col3, #T_b580d_row1_col4, #T_b580d_row1_col5, #T_b580d_row3_col0, #T_b580d_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b580d_row2_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b580d_row2_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# ...

# %%
# построим диаграмму рассеяния для платформы 'WiiU'
sns.set(rc={'figure.figsize':(18,6)})
critic_score_total_sales = sns.scatterplot(data=games_filter_prognoz.query('platform == "WiiU"'), x="critic_score", y="total_sales",
    sizes=(20, 500), legend=False)
#critic_score_total_sales.axes.figtext("Диаграмма рассеяния оценок для платформы 'WiiU'", fontsize=16)
critic_score_total_sales.set(xlim=(10, 100), ylim=(-0.5, 14))
critic_score_total_sales.set_xlabel("Оценка критиков", fontsize=14)
critic_score_total_sales.set_ylabel("Суммарные продажи", fontsize=14)
plt.show()

critic_score_total_sales = sns.scatterplot(data=games_filter_prognoz.query('platform == "WiiU"'), x="user_score", y="total_sales",
    sizes=(20, 500), legend=False)
critic_score_total_sales.set(xlim=(1, 10), ylim=(-0.5, 14))
critic_score_total_sales.set_xlabel("Оценка пользователей", fontsize=14)
critic_score_total_sales.set_ylabel("Суммарные продажи", fontsize=14)
plt.figtext(0.35, 0.00, "Рис.16 - Диаграммы рассеяния оценок для платформы 'WiiU'", fontsize=16)
plt.show()

# %% [markdown]
# **Вывод:** на примере платформ XOne и WiiU мы повторно убедились в том, что чем выше оценка, тем больше продаж не зависимо от того, кто оценил игру (пользователь или критик), а также увидели, что самые дорогие продажи приходятся на самые высокие оценки критиков.

# %% [markdown]
# 9. Посмотрим на общее распределение игр по жанрам.

# %%
(games_filter_prognoz.pivot_table(index='genre',values='total_sales', aggfunc='sum')
.sort_values(by='total_sales', ascending=False).plot(kind='bar',figsize=(18,6)))
plt.xlabel("Жанр", fontsize=12)
plt.ylabel('Суммарные продажи', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.figtext(0.35, -0.2, "Рис.17 - Распределение игр по жанрам", fontsize=16)
plt.show()

# %% [markdown]
# **Вывод:** наиболее популярны игры жанров: экшн,ролевые игры, стрелялки, спортивные, платформер - игры, вызывающие эмоции от происходящего; наименее популярные жанры: симуляции, бои, стратегии, приключения и пазлы -игры, в которых необходимо думать, планировать. Стоит отметить, что на выявленную закономерность также повлияла стоимость игр: производство игр, попавших в популярную группу, обходятся существенно дороже.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Здесь у нас возникла проблема: по суммарным (sum, count) объемам продаж у тебя получилось, что явный лидер - игры в жанре Экшн. Если же ты рассмотришь медианные или средние (mean) значения, то результат поменяется в пользу Шуттеров. Учти тот факт, что игр в жанре Экшн выпускается значительно больше, чем других (в 1,5-2 раза). Доля количества игр в жанре «стрелялок» - всего лишь 8%. Очевидно, что в жанре Экшн присутствует большое количество непопулярных игр с низкими объёмами продаж, в результате чего общий объём продаж жанра "раздут" и берётся количеством, а не качеством. Медиана учитывает не только слишком большие\маленькие значения относительно среднего, но и их количество. Поэтому брать итоговые результаты медианы или среднего более корректно.
#
# В сухом остатке: попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние (или медианные продажи). Я думаю, что анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.</div>

# %% [markdown]
# <a id="id4"></a>
# # 4. Составим портрет пользователя каждого региона

# %% [markdown]
# 1.Определим для пользователя каждого региона (NA, EU, JP) самые популярные платформы (топ-5)

# %%
#Популярные платформы для региона NA
na_sales = games_filter_prognoz.pivot_table(index='platform',values='na_sales', aggfunc='sum').sort_values(by='na_sales', ascending=False)[:5]
na_sales.plot(kind='bar',figsize=(14,4))
plt.xlabel("Платформа", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('NA', fontsize=14)
#plt.figtext(0.35, -0.2, "Рис. - Популярные платформы для региона NA", fontsize=16)
plt.show()

#Популярные платформы для региона EU
eu_sales = games_filter_prognoz.pivot_table(index='platform',values='eu_sales', aggfunc='sum').sort_values(by='eu_sales', ascending=False)[:5]
eu_sales.plot(kind='bar',figsize=(14,4))
plt.xlabel("Платформа", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('EU', fontsize=14)
#plt.figtext(0.35, -0.2, "Рис. - Популярные платформы для региона EU", fontsize=16)
plt.show()

#Популярные платформы для региона JP
jp_sales = games_filter_prognoz.pivot_table(index='platform',values='jp_sales', aggfunc='sum').sort_values(by='jp_sales', ascending=False)[:5]
jp_sales.plot(kind='bar',figsize=(14,4))
plt.xlabel("Платформа", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('JP', fontsize=14)
plt.figtext(0.35, -0.2, "Рис.18 - Популярные платформы для каждого региона", fontsize=16)
plt.show()

# %%
print('ТОП-5 самых популярных платформ в Северной Америке:',*na_sales[:5].index)
print('ТОП-5 самых популярных платформ в Европе:',*eu_sales[:5].index)
print('ТОП-5 самых популярных платформ в Японии:',*jp_sales[:5].index)
# Out:
# ТОП-5 самых популярных платформ в Северной Америке: GBA XB GC PS4 PSP
# ТОП-5 самых популярных платформ в Европе: PS4 PC GBA PSP 3DS
# ТОП-5 самых популярных платформ в Японии: 3DS PSP GBA PSV GC

# %%
# посчитаем долю продаж в Северной Америке 
total_sales = games_filter_prognoz.pivot_table(index='platform', values='total_sales', aggfunc='sum')# переменной присваиваем сумму общих продаж по всем платформам
percent_sales_na = (na_sales['na_sales'] / total_sales['total_sales']* 100)#. # доля продаж в Северной Америке 
print('Доля продаж в Северной Америке:\n',percent_sales_na.sort_values(ascending=False)[:5])
print()
# посчитаем долю продаж в Европе 
percent_sales_eu = (eu_sales['eu_sales'] / total_sales['total_sales']* 100)#. # доля продаж в Европе 
print('Доля продаж в Европе:\n',percent_sales_eu.sort_values(ascending=False)[:5])
print()
# посчитаем долю продаж в Японии
percent_sales_jp = (jp_sales['jp_sales'] / total_sales['total_sales']* 100)#. # доля продаж в Европе 
print('Доля продаж в Японии:\n',percent_sales_jp.sort_values(ascending=False)[:5])
# Out:
# Доля продаж в Северной Америке:
#  platform
# XB     72.360125
# GC     67.066538
# GBA    58.844027
# PSP    37.049701
# PS4    34.615140
# dtype: float64
#
# Доля продаж в Европе:
#  platform
# PC     59.628966
# PS4    44.913096
# GBA    23.838752
# 3DS    23.765564
# PSP    22.664318
# dtype: float64
#
# Доля продаж в Японии:
#  platform
# PSV    40.587251
# 3DS    39.028742
# PSP    26.207992
# GBA    14.884435
# GC     10.847354
# dtype: float64

# %% [markdown]
# **Вывод:** в Северной Америке и Европе пользуются спросом одни и те же игровые платформы с небольшим отличием в распределение лидерства, а вот игровые платформы у японцев значительно отличаются.Однако игровая платформа PS2 пользуется спросом во всех регионах.
# В разы различаются продажи в этих регионах: больше всего продаж в Северной Америке, меньше всего в Японии.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **Однако игровая платформа PS2 пользуется спросом во всех регионах** - где это видно?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА </b>
#
# Допущена опечатка: вместо **PS2** должно быть наименование платформы **PSP**
# </div>

# %% [markdown]
# 2. Определим для пользователя каждого региона (NA, EU, JP) самые популярные жанры (топ-5).

# %%
#популярные жанры в Северной Америке
(games_filter_prognoz.pivot_table(index='genre', values='na_sales', aggfunc='sum')
 .sort_values(by='na_sales', ascending=False)[:5].plot(kind='bar',figsize=(14,4)))
plt.xlabel("жанр", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('NA', fontsize=14)

# популярные жанры в Европе
(games_filter_prognoz.pivot_table(index='genre', values='eu_sales', aggfunc='sum')
 .sort_values(by='eu_sales', ascending=False)[:5].plot(kind='bar',figsize=(14,4)))
plt.xlabel("жанр", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('EU', fontsize=14)

# популярные жанры в Японии
(games_filter_prognoz.pivot_table(index='genre', values='jp_sales', aggfunc='sum')
 .sort_values(by='jp_sales', ascending=False)[:5].plot(kind='bar',figsize=(14,4)))
plt.xlabel("жанр", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('JP', fontsize=14)

plt.figtext(0.35, -0.3, "Рис.19 - Популярные платформы для каждого региона", fontsize=16)
plt.show()

# %% [markdown]
# **Вывод:** в Северной Америке, Европе и Японии популярны одни и те же жанры игр, за исключением жанра "ролевые игры", который имеет большую популярность только у японцев.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# В этих 2х подразделах всё отлично! Предпочтения геймеров 3х регионов в отношении игровых платформ и жанров определены. Ну и вывод соответственно описывает эти отличия.</div>

# %% [markdown]
# 3. Определим влияет ли рейтинг ESRB на продажи в отдельном регионе (NA, EU, JP)

# %%
# рейтинги ESRB на продажи в  Северной Америке
(games_filter_prognoz.pivot_table(index='rating',values='na_sales', aggfunc='sum')
 .sort_values(by='na_sales',ascending=False)[:5].plot(kind='bar',figsize=(18,6)))
plt.xlabel("рейтинг", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('NA', fontsize=14)
plt.show()

# рейтинги ESRB на продажи в Европе 
(games_filter_prognoz.pivot_table(index='rating',values='eu_sales', aggfunc='sum')
 .sort_values(by='eu_sales',ascending=False)[:5].plot(kind='bar',figsize=(18,6)))
plt.xlabel("рейтинг", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('EU', fontsize=14)
plt.show()

# рейтинги ESRB на продажи в Японии 
(games_filter_prognoz.pivot_table(index='rating',values='jp_sales', aggfunc='sum')
 .sort_values(by='jp_sales',ascending=False)[:5].plot(kind='bar',figsize=(18,6)))
plt.xlabel("рейтинг", fontsize=12)
plt.ylabel('Количество продаж', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('JP', fontsize=14)

plt.figtext(0.35, -0.05, "Рис.20 - Влиянеие рейтингов на продажи в регионах", fontsize=16)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Один из подводных камней этого проекта. Суть его в том, что часто студенты в самом начале «тетрадки» пропуски в 'rating' не обрабатывают, оставляют NaN, и соответственно во время анализа и/или построении графиков игры без рейтингов «теряются».</div>

# %% [markdown]
# **Вывод:** зависимость от рейтинга отслеживается во всех трех регионах
# - В Северной Америке и Европе самые высокие рейтинги у игр категории «E» («Everyone») — «Для всех»: содержание вполне подходит для возрастной категории старше 6 лет; такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первой игрой, которая получила данный рейтинг, стала The Simpsons Cartoon Studio, выпущенная в 1996 году.
# - Далее по популярности в Северной Америке следуют игры категории «T» («Teen») — «Подросткам 13—19 лет»: Игра подходит для подростков старше 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики. Примером может являться Rise of the Argonauts.
# - Далее по популярности в Европе следуют игры категории «M» («Mature») — «От 17 лет»: Материалы игры не подходят для возрастной категории младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории. Из последних игр это Saboteur, Left 4 Dead 2.
# - В Японии самые высокие рейтинги у игр, в которых категории не определенны, видимо связано это с менталитетом японцев, далее по популярности категории «M» («Mature»).
# - Остальные жанры менее популярные.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# **В Японии самые высокие рейтинги у игр, в которых категории не определенны, видимо связано это с менталитетом японцев** - рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство (CERO). Получается, что Япония страна со своим менталитетом. И твой анализ показывает, что Японцы в игры-то играют не такие, как весь прочий мир и жанры игр там популярны совсем другие, нежели в остальном мире, да и на рейтинги (не своего агентства) не очень то внимание обращают.</div>

# %% [markdown]
# <a id="id5"></a>
# # 5. Проверим гипотезы
# Пороговое значение alpha примем равным 0.05

# %% [markdown]
# Осуществим проверку гипотез о равенстве средних двух генеральных совокупностей (двухстороннюю): сначала формулируется нулевая гипотеза H₀ о равенстве, далее формулируется альтернативная гипотеза, опровергающая утверждение H₀.

# %% [markdown]
# 1.
# H0: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# H1: Средние пользовательские рейтинги платформ Xbox One и PC разные

# %%
Xbox_One = games_filter_prognoz.query('(platform=="XOne") and (0 < user_score < 100 )')['user_score']
print('Количество игр на платформе Xbox One:', Xbox_One.count())
PC = games_filter_prognoz.query('(platform=="PC")and (0 < user_score < 100 )').user_score
print('Количество игр на платформе PC:',len(PC))
# Out:
# Количество игр на платформе Xbox One: 182
# Количество игр на платформе PC: 728

# %%
# проверяем дисперсии выборок не равенство
if np.var(Xbox_One)==np.var(PC):
    print('True')
else:
    print('False')
# Out:
# False

# %%
# визуализируем распределения
sns.set(rc={'figure.figsize':(18,6)})
sns.histplot(Xbox_One,kde=True, stat="density", linewidth=0)
plt.show()
sns.histplot(PC, kde=True, stat="density", linewidth=0)
plt.show()
plt.figtext(0.3, -0.05, "Рис. 21 - Распределение рейтинга выборок" )
plt.show()

# %% [markdown]
# Распределение Гауссовское, используем Т-критерий Стьюдентса, дисперсии выборок не равны.

# %%
statistics, p = st.ttest_ind(Xbox_One,PC, equal_var=False)
print('Statistics=%.3f, p=%.3f' % (statistics, p))

alpha = 0.05 # 5% критический уровень статистической значимости
if p > alpha:
    print('Средние пользовательские рейтинги платформ Xbox One и PC одинаковые (не получилось отвергнуть H0)')
else:
    print('Средние пользовательские рейтинги платформ Xbox One и PC разные (отвергаем H0)')
# Out:
# Statistics=-4.311, p=0.000
# Средние пользовательские рейтинги платформ Xbox One и PC разные (отвергаем H0)

# %% [markdown]
# 2.
# H0: Средние пользовательские рейтинги жанров Action и Sports одинаковые
# H1: Средние пользовательские рейтинги жанров Action и Sports разные

# %%
Action = games_filter_prognoz.query('(genre=="Action") and (0<user_score<100)')['user_score']
print('Количество игр жанра Action:', Action.count())
Sports = games_filter_prognoz.query('(genre=="Sports") and (0<user_score<100)').user_score
print('Количество игр жанра Sports:', Sports.count())
# Out:
# Количество игр жанра Action: 766
# Количество игр жанра Sports: 414

# %%
# проверяем дисперсии выборок не равенство
if np.var(Action)==np.var(Sports):
    print('True')
else:
    print('False')
# Out:
# False

# %%
# визуализируем распределения
sns.set(rc={'figure.figsize':(18,6)})
sns.histplot(Action,kde=True, stat="density", linewidth=0)
plt.show()
sns.histplot(Sports, kde=True, stat="density", linewidth=0)
plt.show()
plt.figtext(0.3, -0.05, "Рис.22 - Распределение рейтинга выборок" )
plt.show()

# %%
statistics, p = st.ttest_ind(Action,Sports, equal_var=False)
print('Statistics=%.3f, p=%.3f' % (statistics, p))

alpha = 0.05 # 5% критический уровень статистической значимости
if p > alpha:
    print('Средние пользовательские рейтинги жанров Action и Sports одинаковые (не получилось отвергнуть H0)')
else:
    print('Средние пользовательские рейтинги жанров Action и Sports разные (отвергаем H0)')
# Out:
# Statistics=0.027, p=0.978
# Средние пользовательские рейтинги жанров Action и Sports одинаковые (не получилось отвергнуть H0)

# %% [markdown]
# **Вывод:** пользовательские рейтинги для платформ Xbox и PC различны. Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») одинаковые.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что ты не забываешь отфильтровать «заглушки» / NaN значения.
#
# Также верно и то, что мы используем здесь двусторонний тест.
#
# Ну и отлично, что ты понимаешь, что нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».
#
# https://allatambov.github.io/psms/pdf/hypo-test.pdf</div>

# %% [markdown]
# <a id="id6"></a>
# # 6. Вывод:

# %% [markdown]
# Проведя анализ данных о продажах игр, можем отметить, что актуальность компьютерных игр сильно упала по сравнению с началом 2000, когда был расцвет и бурный рост, достигший апогея в 2008-2099 гг, а начиная с 2010 г. наблюдается спад в выпуске, связанный с уходом игр на мобильные устройства. Особые виды игр актуальны и в 2016 г, на их рассмотрении мы остановились более подробно.
# Шестерка самых популярных платформ (PS2, X360, PS3, Wii, DS, PS) набрала свою популярность с начала 2000-х, а период от первых продаж до исчезновения продаж в среднем занимает 13 лет. Максимальные суммарные продажи принесла платформа PS2.
# Исходя из нормального распределения данных за период с 2001 по 2015 год и продолжительности жизни платформ, принято решение в дальнейшем анализе использовать данный период, принимая его за актуальный.
# Исходя из проведенного анализа, выявлены потенциально прибыльные платформы – PS4 и XOne, в которые рекомендуется инвестировать. Данные платформы являются мастодонтами рынка.
# От уровня оценки прямо пропорционально зависят продажи, и не важно оценил игру пользователь или критик. А также самые дорогие продажи приходятся на самые высокие оценки критиков.
# В Северной Америке и Европе пользуются спросом одни и те же игровые платформы с небольшим отличием в распределение лидерства, а вот игровые платформы у японцев значительно отличаются. Однако игровая платформа PS2 пользуется спросом во всех регионах. В разы различаются продажи в этих регионах: больше всего продаж в Северной Америке, меньше всего – в Японии.
# В Северной Америке, Европе и Японии популярны одни и те же жанры игр, наиболее популярны игры жанров: экшн, ролевые игры, стрелялки, спортивные, платформер - игры, вызывающие эмоции от происходящего; наименее популярные жанры: симуляции, бои, стратегии, приключения и пазлы -игры, в которых необходимо думать, планировать. Исключение составляю игры жанра "ролевые игры", которые имеет большую популярность только у японцев.
# Зависимость от рейтинга отслеживается во всех трех регионах:
# -	В Северной Америке и Европе самые высокие рейтинги у игр категории «E» («Everyone») — «Для всех»: содержание вполне подходит для возрастной категории старше 6 лет; такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первой игрой, которая получила данный рейтинг, стала The Simpsons Cartoon Studio, выпущенная в 1996 году.
# -	Далее по популярности в Северной Америке следуют игры категории «T» («Teen») — «Подросткам 13—19 лет»: Игра подходит для подростков старше 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики. Примером может являться Rise of the Argonauts.
# -	Далее по популярности в Европе следуют игры категории «M» («Mature») — «От 17 лет»: Материалы игры не подходят для возрастной категории младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории. Из последних игр это Saboteur, Left 4 Dead 2.
# -	В Японии самые высокие рейтинги у игр, в которых категории не определенны, видимо связано это с менталитетом японцев, далее по популярности категории «M» («Mature»).
#
# Проверка гипотез показала, что:
# - пользовательские рейтинги для платформ Xbox и PC различны.
# - средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») одинаковые.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# После исправления красных комментариев надо будет ещё раз пересмотреть выводы в этом финальном разделе, я уверен, что некоторые акценты сместятся и твой вывод поменяется.
# </div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю высокий уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами.
#
# Ты умело применяешь графические библиотеки (matplotlib / seaborn), выбираешь для визуализации ровно те типы графиков, которые нужны. Очень хорошо, что оси на графиках подписаны и сами они имеют понятные названия.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. Для анализа взят слишком большой интервал. Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал.
#
# 2. В разделе построения «ящика с усами» по глобальным продажам игр в разбивке по платформам необходимо построить график так, чтобы квартили соответствующих «ящиков» позволяли визуально сравнивать платформы между собой. **Все боксплоты** нужно построить на одном графике.
#
# 3. В разделе расчета корреляций между оценками (пользователей/экспертов) и продажами, «на расчет» передаются данные, содержащие «заглушки» (заполненные руками значения).
#
# 4. Попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. Анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.</div>
#
# Эти 4 момента требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: отличная работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.
